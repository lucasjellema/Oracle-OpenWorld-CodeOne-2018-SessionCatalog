# %% [markdown]
# # Exploring Oracle OpenWorld & CodeOne Session Catalog

# %% [markdown]
# The session catalog data is available from a REST API whose root is https://events.rainfocus.com/api/search. Check out Notebook OOW2018 Session Catalog - retrieving raw session data in JSON files.ipynb on how to fetch that data into (raw) local files
#
# This notebook describes how to explore and wrangle and enrich the data from these files.

# %%
import pandas as pd
import json

#as a test, try to load data from one of the generated files 
ss = pd.read_json("oow2018-sessions_oow_TRN.json")
ss
# Out:
#    abbreviation                                           abstract  \
# 0       TRN4070  What if you could benefit from new database qu...
# 1       TRN4026  How does a real-world performance engineer int...
# 10      TRN4567  Understand the tools and techniques available ...
# 11      TRN6620  This session covers the best practices for per...
# 12      TRN4782  Should you refresh your current x86 hardware a...
# 13      TRN1795  Oracle Linux 7 offers the ability to natively ...
# 14      TRN4081  Real-time data is an increasingly popular topi...
# 15      TRN5774  Enterprises need to rapidly react to the chang...
# 16      TRN5777  Digital assistant and chatbot support for any ...
# 17      TRN5792  Do you wish Oracle Digital Assistant could ask...
# 18      TRN4568  In this session learn how to implement and use...
# 19      TRN6615  In this session learn how to set up a simple r...
# 2       TRN4631  This session takes a deep dive into how the Or...
# 20      TRN6616  In this session learn how to shape enterprise ...
# 21      TRN6154  The word “integration” has always conjured up ...
# 22      TRN5157  Consolidating databases requires configuring t...
# 23      TRN6461  This four-hour session will provide an overvie...
# 24      TRN6458  In this four-hour session learn how to meet yo...
# 25      TRN6463  This four-hour session covers secure coding be...
# 26      TRN6460  In this four-hour session learn about Oracle B...
# 27      TRN6462  In this session take a deep-dive into the late...
# 28      TRN6459  In this four-hour session learn how to use the...
# 29      TRN4096  Developers are under increasing  pressure to d...
# 3       TRN3979  Who says setting up and operating mission crit...
# 30      TRN6451  RESTful web services are gaining popularity be...
# 31      TRN6619  This session covers how to use Lambda Expressi...
# 32      TRN6356  Take advantage of the free SaaS application tr...
# 33      TRN1743  Hardware is cheap, the cloud is here, and reso...
# 34      TRN4086  Oracle Database brings unprecedented high avai...
# 35      TRN4106  Encrypting sensitive data has become a must in...
# 36      TRN6963  Integrating Oracle Fusion Applications such as...
# 37      TRN6618  This session explores how to quickly add a RES...
# 38      TRN6617  In this session learn how to filter, compute, ...
# 39      TRN4088  DevOps has become a common practice in the IT ...
# 4       TRN6446  Oracle Approvals Management is a highly extens...
# 40      TRN4499  In this session learn how to unlock even more ...
# 41      TRN4095  Oracle technologies make it easy to include lo...
# 42      TRN4082  How do you get started using Visual Studio to ...
# 43      TRN4032  Do you need global availability and scalabilit...
# 44      TRN4099  In this session gain new insights into your an...
# 45      TRN6511  In this session learn how to apply policies to...
# 46      TRN1918  During this deep-dive session learn how to bui...
# 47      TRN6520  In this session learn how to combine data from...
# 48      TRN6522  In this session learn how to create a user-man...
# 49      TRN6516  In this session learn how to create a web appl...
# 5       TRN4078  Make your applications run without interruptio...
# 6       TRN6352  In this session learn how to meet your applica...
# 7       TRN6168  In this session join development and product m...
# 8       TRN4162  In this session learn how to enable the autono...
# 9       TRN4163  In this session learn about the latest autonom...
#
#     allowDoubleBooking                                    attributevalues  \
# 0                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 1                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 10                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 11                   0  [{'value': 'Product Training Session', 'attrib...
# 12                   0  [{'value': 'Product Training Session', 'attrib...
# 13                   0  [{'value': 'Intermediate', 'attributevalue_id'...
# 14                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 15                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 16                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 17                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 18                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 19                   0  [{'value': 'Product Training Session', 'attrib...
# 2                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 20                   0  [{'value': 'Product Training Session', 'attrib...
# 21                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 22                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 23                   0  [{'value': 'Product Training Session', 'attrib...
# 24                   0  [{'value': '- Integration', 'attributevalue_id...
# 25                   0  [{'value': 'Product Training Session', 'attrib...
# 26                   0  [{'value': 'Product Training Session', 'attrib...
# 27                   0  [{'value': 'Product Training Session', 'attrib...
# 28                   0  [{'value': 'Product Training Session', 'attrib...
# 29                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 3                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 30                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 31                   0  [{'value': 'Product Training Session', 'attrib...
# 32                   0  [{'value': 'Product Training Session', 'attrib...
# 33                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 34                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 35                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 36                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 37                   0  [{'value': 'Product Training Session', 'attrib...
# 38                   0  [{'value': 'Product Training Session', 'attrib...
# 39                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 4                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 40                   0  [{'value': 'Advanced', 'attributevalue_id': '1...
# 41                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 42                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 43                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 44                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 45                   0  [{'value': 'Product Training Session', 'attrib...
# 46                   0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 47                   0  [{'value': 'Product Training Session', 'attrib...
# 48                   0  [{'value': 'Product Training Session', 'attrib...
# 49                   0  [{'value': 'Product Training Session', 'attrib...
# 5                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 6                    0  [{'value': 'Product Training Session', 'attrib...
# 7                    0  [{'value': 'Beginner', 'attributevalue_id': '1...
# 8                    0  [{'value': 'Intermediate', 'attributevalue_id'...
# 9                    0  [{'value': 'Intermediate', 'attributevalue_id'...
#
#        code                              codeParts  code_id  \
# 0   TRN4070  {'alpha0': 'TRN', 'numeric1': '4070'}  trn4070
# 1   TRN4026  {'alpha0': 'TRN', 'numeric1': '4026'}  trn4026
# 10  TRN4567  {'alpha0': 'TRN', 'numeric1': '4567'}  trn4567
# 11  TRN6620  {'alpha0': 'TRN', 'numeric1': '6620'}  trn6620
# 12  TRN4782  {'alpha0': 'TRN', 'numeric1': '4782'}  trn4782
# 13  TRN1795  {'alpha0': 'TRN', 'numeric1': '1795'}  trn1795
# 14  TRN4081  {'alpha0': 'TRN', 'numeric1': '4081'}  trn4081
# 15  TRN5774  {'alpha0': 'TRN', 'numeric1': '5774'}  trn5774
# 16  TRN5777  {'alpha0': 'TRN', 'numeric1': '5777'}  trn5777
# 17  TRN5792  {'alpha0': 'TRN', 'numeric1': '5792'}  trn5792
# 18  TRN4568  {'alpha0': 'TRN', 'numeric1': '4568'}  trn4568
# 19  TRN6615  {'alpha0': 'TRN', 'numeric1': '6615'}  trn6615
# 2   TRN4631  {'alpha0': 'TRN', 'numeric1': '4631'}  trn4631
# 20  TRN6616  {'alpha0': 'TRN', 'numeric1': '6616'}  trn6616
# 21  TRN6154  {'alpha0': 'TRN', 'numeric1': '6154'}  trn6154
# 22  TRN5157  {'alpha0': 'TRN', 'numeric1': '5157'}  trn5157
# 23  TRN6461  {'alpha0': 'TRN', 'numeric1': '6461'}  trn6461
# 24  TRN6458  {'alpha0': 'TRN', 'numeric1': '6458'}  trn6458
# 25  TRN6463  {'alpha0': 'TRN', 'numeric1': '6463'}  trn6463
# 26  TRN6460  {'alpha0': 'TRN', 'numeric1': '6460'}  trn6460
# 27  TRN6462  {'alpha0': 'TRN', 'numeric1': '6462'}  trn6462
# 28  TRN6459  {'alpha0': 'TRN', 'numeric1': '6459'}  trn6459
# 29  TRN4096  {'alpha0': 'TRN', 'numeric1': '4096'}  trn4096
# 3   TRN3979  {'alpha0': 'TRN', 'numeric1': '3979'}  trn3979
# 30  TRN6451  {'alpha0': 'TRN', 'numeric1': '6451'}  trn6451
# 31  TRN6619  {'alpha0': 'TRN', 'numeric1': '6619'}  trn6619
# 32  TRN6356  {'alpha0': 'TRN', 'numeric1': '6356'}  trn6356
# 33  TRN1743  {'alpha0': 'TRN', 'numeric1': '1743'}  trn1743
# 34  TRN4086  {'alpha0': 'TRN', 'numeric1': '4086'}  trn4086
# 35  TRN4106  {'alpha0': 'TRN', 'numeric1': '4106'}  trn4106
# 36  TRN6963  {'alpha0': 'TRN', 'numeric1': '6963'}  trn6963
# 37  TRN6618  {'alpha0': 'TRN', 'numeric1': '6618'}  trn6618
# 38  TRN6617  {'alpha0': 'TRN', 'numeric1': '6617'}  trn6617
# 39  TRN4088  {'alpha0': 'TRN', 'numeric1': '4088'}  trn4088
# 4   TRN6446  {'alpha0': 'TRN', 'numeric1': '6446'}  trn6446
# 40  TRN4499  {'alpha0': 'TRN', 'numeric1': '4499'}  trn4499
# 41  TRN4095  {'alpha0': 'TRN', 'numeric1': '4095'}  trn4095
# 42  TRN4082  {'alpha0': 'TRN', 'numeric1': '4082'}  trn4082
# 43  TRN4032  {'alpha0': 'TRN', 'numeric1': '4032'}  trn4032
# 44  TRN4099  {'alpha0': 'TRN', 'numeric1': '4099'}  trn4099
# 45  TRN6511  {'alpha0': 'TRN', 'numeric1': '6511'}  trn6511
# 46  TRN1918  {'alpha0': 'TRN', 'numeric1': '1918'}  trn1918
# 47  TRN6520  {'alpha0': 'TRN', 'numeric1': '6520'}  trn6520
# 48  TRN6522  {'alpha0': 'TRN', 'numeric1': '6522'}  trn6522
# 49  TRN6516  {'alpha0': 'TRN', 'numeric1': '6516'}  trn6516
# 5   TRN4078  {'alpha0': 'TRN', 'numeric1': '4078'}  trn4078
# 6   TRN6352  {'alpha0': 'TRN', 'numeric1': '6352'}  trn6352
# 7   TRN6168  {'alpha0': 'TRN', 'numeric1': '6168'}  trn6168
# 8   TRN4162  {'alpha0': 'TRN', 'numeric1': '4162'}  trn4162
# 9   TRN4163  {'alpha0': 'TRN', 'numeric1': '4163'}  trn4163
#
#           es_metadata_id             event eventCode      ...        \
# 0   1523650128750001VI1i  Oracle OpenWorld     oow18      ...
# 1   1523576222383001pdRl  Oracle OpenWorld     oow18      ...
# 10  1524514304383001hANs  Oracle OpenWorld     oow18      ...
# 11  1536229519095001xpnW  Oracle OpenWorld     oow18      ...
# 12  1525201315264001Q57I  Oracle OpenWorld     oow18      ...
# 13  1521584393410001jJxz  Oracle OpenWorld     oow18      ...
# 14  1523652232625001KxHD  Oracle OpenWorld     oow18      ...
# 15  1526173783263001pwyK  Oracle OpenWorld     oow18      ...
# 16  1526178982547001cT4x  Oracle OpenWorld     oow18      ...
# 17  1526263337829001cLQF  Oracle OpenWorld     oow18      ...
# 18  1524514522390001dt1A  Oracle OpenWorld     oow18      ...
# 19  1536229518365001xr6g  Oracle OpenWorld     oow18      ...
# 2   1524589840877001mdKy  Oracle OpenWorld     oow18      ...
# 20  1536229518524001xOAR  Oracle OpenWorld     oow18      ...
# 21  1527101771724001fyyh  Oracle OpenWorld     oow18      ...
# 22  1525883960936001hOlX  Oracle OpenWorld     oow18      ...
# 23  1533296972502001hjO2  Oracle OpenWorld     oow18      ...
# 24  1533296972098001hW6u  Oracle OpenWorld     oow18      ...
# 25  1533296972761001hvsN  Oracle OpenWorld     oow18      ...
# 26  1533296972366001hvbt  Oracle OpenWorld     oow18      ...
# 27  1533296972632001hQFL  Oracle OpenWorld     oow18      ...
# 28  1533296972233001h2qF  Oracle OpenWorld     oow18      ...
# 29  1523654165761001O6rW  Oracle OpenWorld     oow18      ...
# 3   1523249994892001tVzz  Oracle OpenWorld     oow18      ...
# 30  1533153452046001TCWu  Oracle OpenWorld     oow18      ...
# 31  1536229518955001xd8d  Oracle OpenWorld     oow18      ...
# 32  15321279150520012lS8  Oracle OpenWorld     oow18      ...
# 33  1521566926420001ErhG  Oracle OpenWorld     oow18      ...
# 34  1523652867452001fmnB  Oracle OpenWorld     oow18      ...
# 35  1523674440886001eVbL  Oracle OpenWorld     oow18      ...
# 36  1538758498611001RBJV  Oracle OpenWorld     oow18      ...
# 37  1536229518815001xCqF  Oracle OpenWorld     oow18      ...
# 38  1536229518666001xW1J  Oracle OpenWorld     oow18      ...
# 39  15236532902550010MO8  Oracle OpenWorld     oow18      ...
# 4   1533151030443001fXL7  Oracle OpenWorld     oow18      ...
# 40  1524383723620001yLva  Oracle OpenWorld     oow18      ...
# 41  1523654117819001O4x1  Oracle OpenWorld     oow18      ...
# 42  1523652330881001pJVZ  Oracle OpenWorld     oow18      ...
# 43  1523580486933001BeDM  Oracle OpenWorld     oow18      ...
# 44  1523655277489001m9pi  Oracle OpenWorld     oow18      ...
# 45  15342556258820018kgU  Oracle OpenWorld     oow18      ...
# 46  1521635484691001CmT7  Oracle OpenWorld     oow18      ...
# 47  153425562711200186T0  Oracle OpenWorld     oow18      ...
# 48  15342556273860018WtJ  Oracle OpenWorld     oow18      ...
# 49  15342556265770018lWA  Oracle OpenWorld     oow18      ...
# 5   1523651831516001Bgvj  Oracle OpenWorld     oow18      ...
# 6   15321279145360012ViL  Oracle OpenWorld     oow18      ...
# 7   1527206231045001JiNQ  Oracle OpenWorld     oow18      ...
# 8   1523842112107001Ac1K  Oracle OpenWorld     oow18      ...
# 9   1523842475121001AGpg  Oracle OpenWorld     oow18      ...
#
#    type_displayorder type_displayorder_string useDoubleBooking  \
# 0               9999                     9999             True
# 1               9999                     9999             True
# 10              9999                     9999             True
# 11              9999                     9999             True
# 12              9999                     9999             True
# 13              9999                     9999             True
# 14              9999                     9999             True
# 15              9999                     9999             True
# 16              9999                     9999             True
# 17              9999                     9999             True
# 18              9999                     9999             True
# 19              9999                     9999             True
# 2               9999                     9999             True
# 20              9999                     9999             True
# 21              9999                     9999             True
# 22              9999                     9999             True
# 23              9999                     9999             True
# 24              9999                     9999             True
# 25              9999                     9999             True
# 26              9999                     9999             True
# 27              9999                     9999             True
# 28              9999                     9999             True
# 29              9999                     9999             True
# 3               9999                     9999             True
# 30              9999                     9999             True
# 31              9999                     9999             True
# 32              9999                     9999             True
# 33              9999                     9999             True
# 34              9999                     9999             True
# 35              9999                     9999             True
# 36              9999                     9999             True
# 37              9999                     9999             True
# 38              9999                     9999             True
# 39              9999                     9999             True
# 4               9999                     9999             True
# 40              9999                     9999             True
# 41              9999                     9999             True
# 42              9999                     9999             True
# 43              9999                     9999             True
# 44              9999                     9999             True
# 45              9999                     9999             True
# 46              9999                     9999             True
# 47              9999                     9999             True
# 48              9999                     9999             True
# 49              9999                     9999             True
# 5               9999                     9999             True
# 6               9999                     9999             True
# 7               9999                     9999             True
# 8               9999                     9999             True
# 9               9999                     9999             True
#
#     useWaitingList videos                                         viewAccess  \
# 0                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 1                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 10               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 11               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 12               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 13               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 14               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 15               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 16               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 17               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 18               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 19               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 2                0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 20               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 21               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 22               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 23               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 24               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 25               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 26               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 27               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 28               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 29               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 3                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 30               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 31               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 32               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 33               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 34               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 35               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 36               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 37               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 38               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 39               0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 4                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 40               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 41               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 42               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 43               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 44               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 45               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 46               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 47               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 48               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 49               0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 5                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 6                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 7                0   None  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 8                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
# 9                0     []  [1533140082245001une2, 1533141196635001EZdJ, 1...
#
#     viewAccessPublic viewFileAccess  \
# 0               True             []
# 1               True             []
# 10              True             []
# 11              True             []
# 12              True             []
# 13              True             []
# 14              True             []
# 15              True             []
# 16              True             []
# 17              True             []
# 18              True             []
# 19              True             []
# 2               True             []
# 20              True             []
# 21              True             []
# 22              True             []
# 23              True             []
# 24              True             []
# 25              True             []
# 26              True             []
# 27              True             []
# 28              True             []
# 29              True             []
# 3               True             []
# 30              True             []
# 31              True             []
# 32              True             []
# 33              True             []
# 34              True             []
# 35              True             []
# 36              True             []
# 37              True             []
# 38              True             []
# 39              True             []
# 4               True             []
# 40              True             []
# 41              True             []
# 42              True             []
# 43              True             []
# 44              True             []
# 45              True             []
# 46              True             []
# 47              True             []
# 48              True             []
# 49              True             []
# 5               True             []
# 6               True             []
# 7               True             []
# 8               True             []
# 9               True             []
#
#                                   waitlistAccess  waitlistLimit
# 0   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 1   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 10  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 11  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 12  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 13  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 14  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 15  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 16  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 17  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 18  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 19  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 2   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 20  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 21  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 22  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 23  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 24  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 25  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 26  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 27  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 28  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 29  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 3   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 30  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 31  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 32  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 33  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 34  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 35  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 36  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 37  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 38  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 39  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 4   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 40  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 41  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 42  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 43  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 44  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 45  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 46  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 47  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 48  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 49  [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 5   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 6   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 7   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 8   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
# 9   [1533141196635001EZdJ, 1533143193464001uQsQ]              0
#
# [50 rows x 37 columns]

# %% [markdown]
# Below is the result of making a request for session details. The really interesting stuff is hidden in the first element of the sectionList array.

# %% [markdown]
# Remove the unwanted columns from the Dataframe
# (allowDoubleBooking .'codeParts', 'code_id', 'es_metadata_id',type_displayorder	type_displayorder_string	useDoubleBooking	useWaitingList	videos	viewAccess	viewAccessPublic, ...)

# %%
#list all columns in the Dataframe
ss.columns
# Out:
# Index(['abbreviation', 'abstract', 'allowDoubleBooking', 'attributevalues',
#        'code', 'codeParts', 'code_id', 'es_metadata_id', 'event', 'eventCode',
#        'eventId', 'eventName', 'externalID', 'featured_value', 'files',
#        'highlight', 'length', 'participants', 'publicViewPrivateSchedule',
#        'published', 'scheduleAccess', 'sessionID', 'status', 'times', 'title',
#        'title_sort', 'type', 'type_displayorder', 'type_displayorder_string',
#        'useDoubleBooking', 'useWaitingList', 'videos', 'viewAccess',
#        'viewAccessPublic', 'viewFileAccess', 'waitlistAccess',
#        'waitlistLimit'],
#       dtype='object')

# %%
# remove columns
# Note that the original 'data' object is changed when inplace=True
ss.drop([
    'allowDoubleBooking'
         ,'codeParts', 'code_id', 'es_metadata_id','type_displayorder'
       ,'type_displayorder_string', 'useDoubleBooking'
       ,'useWaitingList', 'videos'
      , 'viewAccess', 'viewAccessPublic','viewFileAccess', 'waitlistAccess', 'waitlistLimit'
    ,  'eventId','eventName','featured_value','publicViewPrivateSchedule','published', 'scheduleAccess','sessionID','status'
    ,'externalID','highlight','abbreviation'
        ]
        , axis=1, inplace=True)

# %%
ss
# Out:
#                                              abstract  \
# 0   What if you could benefit from new database qu...
# 1   How does a real-world performance engineer int...
# 10  Understand the tools and techniques available ...
# 11  This session covers the best practices for per...
# 12  Should you refresh your current x86 hardware a...
# 13  Oracle Linux 7 offers the ability to natively ...
# 14  Real-time data is an increasingly popular topi...
# 15  Enterprises need to rapidly react to the chang...
# 16  Digital assistant and chatbot support for any ...
# 17  Do you wish Oracle Digital Assistant could ask...
# 18  In this session learn how to implement and use...
# 19  In this session learn how to set up a simple r...
# 2   This session takes a deep dive into how the Or...
# 20  In this session learn how to shape enterprise ...
# 21  The word “integration” has always conjured up ...
# 22  Consolidating databases requires configuring t...
# 23  This four-hour session will provide an overvie...
# 24  In this four-hour session learn how to meet yo...
# 25  This four-hour session covers secure coding be...
# 26  In this four-hour session learn about Oracle B...
# 27  In this session take a deep-dive into the late...
# 28  In this four-hour session learn how to use the...
# 29  Developers are under increasing  pressure to d...
# 3   Who says setting up and operating mission crit...
# 30  RESTful web services are gaining popularity be...
# 31  This session covers how to use Lambda Expressi...
# 32  Take advantage of the free SaaS application tr...
# 33  Hardware is cheap, the cloud is here, and reso...
# 34  Oracle Database brings unprecedented high avai...
# 35  Encrypting sensitive data has become a must in...
# 36  Integrating Oracle Fusion Applications such as...
# 37  This session explores how to quickly add a RES...
# 38  In this session learn how to filter, compute, ...
# 39  DevOps has become a common practice in the IT ...
# 4   Oracle Approvals Management is a highly extens...
# 40  In this session learn how to unlock even more ...
# 41  Oracle technologies make it easy to include lo...
# 42  How do you get started using Visual Studio to ...
# 43  Do you need global availability and scalabilit...
# 44  In this session gain new insights into your an...
# 45  In this session learn how to apply policies to...
# 46  During this deep-dive session learn how to bui...
# 47  In this session learn how to combine data from...
# 48  In this session learn how to create a user-man...
# 49  In this session learn how to create a web appl...
# 5   Make your applications run without interruptio...
# 6   In this session learn how to meet your applica...
# 7   In this session join development and product m...
# 8   In this session learn how to enable the autono...
# 9   In this session learn about the latest autonom...
#
#                                       attributevalues     code  \
# 0   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4070
# 1   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4026
# 10  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4567
# 11  [{'value': 'Product Training Session', 'attrib...  TRN6620
# 12  [{'value': 'Product Training Session', 'attrib...  TRN4782
# 13  [{'value': 'Intermediate', 'attributevalue_id'...  TRN1795
# 14  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4081
# 15  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5774
# 16  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5777
# 17  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5792
# 18  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4568
# 19  [{'value': 'Product Training Session', 'attrib...  TRN6615
# 2   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4631
# 20  [{'value': 'Product Training Session', 'attrib...  TRN6616
# 21  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6154
# 22  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5157
# 23  [{'value': 'Product Training Session', 'attrib...  TRN6461
# 24  [{'value': '- Integration', 'attributevalue_id...  TRN6458
# 25  [{'value': 'Product Training Session', 'attrib...  TRN6463
# 26  [{'value': 'Product Training Session', 'attrib...  TRN6460
# 27  [{'value': 'Product Training Session', 'attrib...  TRN6462
# 28  [{'value': 'Product Training Session', 'attrib...  TRN6459
# 29  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4096
# 3   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN3979
# 30  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6451
# 31  [{'value': 'Product Training Session', 'attrib...  TRN6619
# 32  [{'value': 'Product Training Session', 'attrib...  TRN6356
# 33  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1743
# 34  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4086
# 35  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4106
# 36  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6963
# 37  [{'value': 'Product Training Session', 'attrib...  TRN6618
# 38  [{'value': 'Product Training Session', 'attrib...  TRN6617
# 39  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4088
# 4   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6446
# 40  [{'value': 'Advanced', 'attributevalue_id': '1...  TRN4499
# 41  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4095
# 42  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4082
# 43  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4032
# 44  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4099
# 45  [{'value': 'Product Training Session', 'attrib...  TRN6511
# 46  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1918
# 47  [{'value': 'Product Training Session', 'attrib...  TRN6520
# 48  [{'value': 'Product Training Session', 'attrib...  TRN6522
# 49  [{'value': 'Product Training Session', 'attrib...  TRN6516
# 5   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4078
# 6   [{'value': 'Product Training Session', 'attrib...  TRN6352
# 7   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6168
# 8   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4162
# 9   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4163
#
#                event eventCode  \
# 0   Oracle OpenWorld     oow18
# 1   Oracle OpenWorld     oow18
# 10  Oracle OpenWorld     oow18
# 11  Oracle OpenWorld     oow18
# 12  Oracle OpenWorld     oow18
# 13  Oracle OpenWorld     oow18
# 14  Oracle OpenWorld     oow18
# 15  Oracle OpenWorld     oow18
# 16  Oracle OpenWorld     oow18
# 17  Oracle OpenWorld     oow18
# 18  Oracle OpenWorld     oow18
# 19  Oracle OpenWorld     oow18
# 2   Oracle OpenWorld     oow18
# 20  Oracle OpenWorld     oow18
# 21  Oracle OpenWorld     oow18
# 22  Oracle OpenWorld     oow18
# 23  Oracle OpenWorld     oow18
# 24  Oracle OpenWorld     oow18
# 25  Oracle OpenWorld     oow18
# 26  Oracle OpenWorld     oow18
# 27  Oracle OpenWorld     oow18
# 28  Oracle OpenWorld     oow18
# 29  Oracle OpenWorld     oow18
# 3   Oracle OpenWorld     oow18
# 30  Oracle OpenWorld     oow18
# 31  Oracle OpenWorld     oow18
# 32  Oracle OpenWorld     oow18
# 33  Oracle OpenWorld     oow18
# 34  Oracle OpenWorld     oow18
# 35  Oracle OpenWorld     oow18
# 36  Oracle OpenWorld     oow18
# 37  Oracle OpenWorld     oow18
# 38  Oracle OpenWorld     oow18
# 39  Oracle OpenWorld     oow18
# 4   Oracle OpenWorld     oow18
# 40  Oracle OpenWorld     oow18
# 41  Oracle OpenWorld     oow18
# 42  Oracle OpenWorld     oow18
# 43  Oracle OpenWorld     oow18
# 44  Oracle OpenWorld     oow18
# 45  Oracle OpenWorld     oow18
# 46  Oracle OpenWorld     oow18
# 47  Oracle OpenWorld     oow18
# 48  Oracle OpenWorld     oow18
# 49  Oracle OpenWorld     oow18
# 5   Oracle OpenWorld     oow18
# 6   Oracle OpenWorld     oow18
# 7   Oracle OpenWorld     oow18
# 8   Oracle OpenWorld     oow18
# 9   Oracle OpenWorld     oow18
#
#                                                 files  length  \
# 0   [{'fileId': '1540594881063001PjdE', 'filename'...      45
# 1   [{'fileId': '1540053090863001JeFM', 'filename'...      45
# 10  [{'fileId': '1539988618000001VcCe', 'filename'...      45
# 11                                               None      20
# 12  [{'fileId': '1541718307822001nnE5', 'filename'...      45
# 13  [{'fileId': '1540823655456001S2yU', 'filename'...      45
# 14  [{'fileId': '1540586960748001awpB', 'filename'...      45
# 15  [{'fileId': '1540498947195001Q0Ng', 'filename'...      45
# 16  [{'fileId': '1540304567821001vNsN', 'filename'...      45
# 17  [{'fileId': '1542151051287001R7i9', 'filename'...      45
# 18  [{'fileId': '1540476654486001kh1V', 'filename'...      45
# 19  [{'fileId': '1539815634830001z0Yt', 'filename'...      20
# 2                                                None      45
# 20  [{'fileId': '1540138774225001QP4j', 'filename'...      20
# 21                                               None      45
# 22  [{'fileId': '1542289822562001Wyh2', 'filename'...      45
# 23  [{'fileId': '1540267572704001DPfY', 'filename'...     240
# 24  [{'fileId': '1539983113140001dUD6', 'filename'...     240
# 25                                               None     240
# 26  [{'fileId': '1540527681659001JDvx', 'filename'...     240
# 27  [{'fileId': '1540231956194001DVjv', 'filename'...     240
# 28  [{'fileId': '1539725236806001lwQU', 'filename'...     240
# 29  [{'fileId': '1540795935251001S515', 'filename'...      45
# 3   [{'fileId': '1540586876838001Ph9B', 'filename'...      45
# 30  [{'fileId': '15401387571180016fMd', 'filename'...      45
# 31                                               None      20
# 32                                               None      45
# 33  [{'fileId': '1540792881998001P1gG', 'filename'...      45
# 34  [{'fileId': '1540524901214001DeiN', 'filename'...      45
# 35  [{'fileId': '1540946073032001t4Xq', 'filename'...      45
# 36  [{'fileId': '1540835441272001sbxy', 'filename'...      45
# 37  [{'fileId': '1540138803558001Jt4Z', 'filename'...      20
# 38  [{'fileId': '1540138790214001vcVs', 'filename'...      20
# 39                                               None      45
# 4   [{'fileId': '1539815058569001lvIK', 'filename'...      45
# 40  [{'fileId': '15414557470710017n4B', 'filename'...      45
# 41  [{'fileId': '1540906576250001scXJ', 'filename'...      45
# 42  [{'fileId': '1543251169356001Rr8J', 'filename'...      45
# 43  [{'fileId': '1541456703248001Bmgl', 'filename'...      45
# 44  [{'fileId': '1540993657058001xLIc', 'filename'...      45
# 45  [{'fileId': '1539983314113001Ddd3', 'filename'...      20
# 46  [{'fileId': '1540133033796001JEIg', 'filename'...      45
# 47  [{'fileId': '1540221835507001QL6R', 'filename'...      20
# 48  [{'fileId': '1540220944732001JNkX', 'filename'...      20
# 49  [{'fileId': '1539983570031001QKVJ', 'filename'...      20
# 5   [{'fileId': '1540591572080001fr6Q', 'filename'...      45
# 6   [{'fileId': '1539979883463001Voaf', 'filename'...      45
# 7                                                None      45
# 8   [{'fileId': '1541467971650001UYFt', 'filename'...      45
# 9   [{'fileId': '1540528741382001Q6i3', 'filename'...      45
#
#                                          participants  \
# 0   [{'speakerId': '14574694377280015QNA_150393630...
# 1   [{'speakerId': '145746969078000151fg_150393630...
# 10  [{'speakerId': '1468532302119001DtNf_150393630...
# 11  [{'speakerId': '1470698803884001CfwZ_150393630...
# 12  [{'speakerId': '14574694661200015oeh_150393630...
# 13  [{'speakerId': '1521580422142001cXpX_150393630...
# 14  [{'speakerId': '14574694955970015EaV_150393630...
# 15  [{'speakerId': '14574696964400015ReA_150393630...
# 16  [{'speakerId': '1462125550493001D3Xz_150393630...
# 17  [{'speakerId': '1515103283372001FgzI_150393630...
# 18  [{'speakerId': '1472560122691001TA73_150393630...
# 19  [{'speakerId': '1533151159169001TlLV_150393630...
# 2   [{'speakerId': '15315177009490016aEX_150393630...
# 20  [{'speakerId': '1533153526686001aze0_150393630...
# 21  [{'speakerId': '14574697717300035Hxm_150393630...
# 22  [{'speakerId': '14574694775980015e0D_150393630...
# 23  [{'speakerId': '1467230960339001h4Nj_150393630...
# 24  [{'speakerId': '1500580326390001qTtd_150393630...
# 25  [{'speakerId': '1470698803884001CfwZ_150393630...
# 26  [{'speakerId': '14664511836130012Qxc_150393630...
# 27  [{'speakerId': '1500578268510001KsST_150393630...
# 28  [{'speakerId': '1467230528322001hGg0_150393630...
# 29  [{'speakerId': '14574694988420015Jbn_150393630...
# 3   [{'speakerId': '14574694525770015tTj_150393630...
# 30  [{'speakerId': '1533153526686001aze0_150393630...
# 31  [{'speakerId': '1470698803884001CfwZ_150393630...
# 32  [{'speakerId': '14574696120130015JlG_150393630...
# 33  [{'speakerId': '145746943683700158HC_150393630...
# 34  [{'speakerId': '14574694354950015iFv_150393630...
# 35  [{'speakerId': '14574696616110015fCp_150393630...
# 36  [{'speakerId': '14574694733280025bh3_150393630...
# 37  [{'speakerId': '1533153526686001aze0_150393630...
# 38  [{'speakerId': '1533153526686001aze0_150393630...
# 39  [{'speakerId': '14574694370360025gMe_150393630...
# 4   [{'speakerId': '1533151159169001TlLV_150393630...
# 40  [{'speakerId': '14574697206660015bfV_150393630...
# 41  [{'speakerId': '14574694762980015eve_150393630...
# 42  [{'speakerId': '14574694748550015JRe_150393630...
# 43  [{'speakerId': '14574695098990015wUk_150393630...
# 44  [{'speakerId': '14574694711340015m5k_150393630...
# 45  [{'speakerId': '1500580326390001qTtd_150393630...
# 46  [{'speakerId': '145746944760700159kb_150393630...
# 47  [{'speakerId': '14574694422520015XTf_150393630...
# 48  [{'speakerId': '14574694422520015XTf_150393630...
# 49  [{'speakerId': '1500580326390001qTtd_150393630...
# 5   [{'speakerId': '14574694639010015kGi_150393630...
# 6   [{'speakerId': '1500580326390001qTtd_150393630...
# 7   [{'speakerId': '14574694685180025oHC_150393630...
# 8   [{'speakerId': '14574694459920025cpR_150393630...
# 9   [{'speakerId': '14574695070120015ey6_150393630...
#
#                                                 times  \
# 0   [{'sessionTimeID': '1532616475210001usPa', 'se...
# 1   [{'sessionTimeID': '1531945554973001z4Hi', 'se...
# 10  [{'sessionTimeID': '15352384203600012G04', 'se...
# 11  [{'sessionTimeID': '1538112369718001MoR2', 'se...
# 12  [{'sessionTimeID': '1535044864680001SZQw', 'se...
# 13  [{'sessionTimeID': '1535047180566001tTGP', 'se...
# 14  [{'sessionTimeID': '1531854081960001fkV5', 'se...
# 15  [{'sessionTimeID': '1533759384227001uIZh', 'se...
# 16  [{'sessionTimeID': '1533759287589001DyMn', 'se...
# 17  [{'sessionTimeID': '1533797930591001DtuZ', 'se...
# 18  [{'sessionTimeID': '1534548822332001jDNv', 'se...
# 19  [{'sessionTimeID': '15381125187210018fbH', 'se...
# 2   [{'sessionTimeID': '1535697245338001x3yZ', 'se...
# 20  [{'sessionTimeID': '1538112267267001PV2e', 'se...
# 21  [{'sessionTimeID': '1536195528781001YHbb', 'se...
# 22  [{'sessionTimeID': '1532734468296001S4ra', 'se...
# 23  [{'sessionTimeID': '1537150614045001Fc1v', 'se...
# 24  [{'sessionTimeID': '1537255427664001P8OT', 'se...
# 25  [{'sessionTimeID': '1537150687958001eoZ7', 'se...
# 26  [{'sessionTimeID': '1537150650927001PHnW', 'se...
# 27  [{'sessionTimeID': '1537150669415001Foxx', 'se...
# 28  [{'sessionTimeID': '1537150593997001PXcV', 'se...
# 29  [{'sessionTimeID': '1531854038107001ankr', 'se...
# 3   [{'sessionTimeID': '1531859121810001TdYU', 'se...
# 30  [{'sessionTimeID': '1535316983456001BNUt', 'se...
# 31  [{'sessionTimeID': '1538112283675001MFof', 'se...
# 32  [{'sessionTimeID': '15352234095720011o4W', 'se...
# 33  [{'sessionTimeID': '1535170950479001Bqi3', 'se...
# 34  [{'sessionTimeID': '1531849969460001fzY3', 'se...
# 35  [{'sessionTimeID': '1531769844473001acP5', 'se...
# 36  [{'sessionTimeID': '1539627763346001Nol6', 'se...
# 37  [{'sessionTimeID': '1538112532706001Pb5D', 'se...
# 38  [{'sessionTimeID': '1538112427579001MNeY', 'se...
# 39  [{'sessionTimeID': '1531848290901001fiBN', 'se...
# 4   [{'sessionTimeID': '15353154410710012PiP', 'se...
# 40  [{'sessionTimeID': '1535046699651001SvIb', 'se...
# 41  [{'sessionTimeID': '1531946578948001zDRs', 'se...
# 42  [{'sessionTimeID': '1531849529027001TJcf', 'se...
# 43  [{'sessionTimeID': '15320334995950015aXk', 'se...
# 44  [{'sessionTimeID': '1531945644126001zzma', 'se...
# 45  [{'sessionTimeID': '15381123375010018r1z', 'se...
# 46  [{'sessionTimeID': '1533758776080001MDuW', 'se...
# 47  [{'sessionTimeID': '1538112351906001PAkt', 'se...
# 48  [{'sessionTimeID': '1538112737368001PGzW', 'se...
# 49  [{'sessionTimeID': '1538112695700001MkPC', 'se...
# 5   [{'sessionTimeID': '1531853834216001TVkZ', 'se...
# 6   [{'sessionTimeID': '1535317184544001BYVj', 'se...
# 7   [{'sessionTimeID': '15343996004640012QHh', 'se...
# 8   [{'sessionTimeID': '1531861316059001fOyC', 'se...
# 9   [{'sessionTimeID': '1531861261596001T69W', 'se...
#
#                                                 title  \
# 0   A Database Proxy for Transparent High Availabi...
# 1   A Day in the Life of a Real-World Performance ...
# 10  Best Practices for Diagnosing and Troubleshoot...
# 11  Best Practices for Enterprise Application Perf...
# 12  Best Practices for Going Hybrid with Oracle's ...
# 13  Building Firewalls and Load Balancers on Oracl...
# 14  Building Real-Time Data in Web Applications wi...
# 15  Build Mobile/Progressive Web Apps: Oracle Visu...
# 16  Build Multilingual Digital Assistants/Chatbots...
# 17  Chat With Oracle SaaS Cloud Apps using Your Or...
# 18  Configure, Diagnose, Troubleshoot Security Ass...
# 19  Create a Rule in Oracle E-Business Tax to Dete...
# 2   A Deep Dive into Oracle's Artificial Intellige...
# 20  Create Database REST APIs for Mobile Apps Usin...
# 21  Creating and Maintaining Commerce Integrations...
# 22  Database Consolidation: Best Practices for Suc...
# 23  Deep Dive: An Introduction to Workflow Approva...
# 24  Deep Dive: Application Integration on Oracle C...
# 25       Deep Dive: Java Secure Coding Best Practices
# 26  Deep Dive: Oracle Big Data/Oracle Big Data Clo...
# 27  Deep Dive: Oracle Database 18c New Features: C...
# 28  Deep Dive: Oracle HCM Cloud: Getting Started w...
# 29  Developers: Don’t Be the Person Who Discombobu...
# 3   An Insider’s Guide to Oracle Autonomous Transa...
# 30  Develop, Implement, and Maintain Database REST...
# 31  Develop Robust Enterprise Applications with Ja...
# 32  Diamonds May Be Forever but Platinum Is Now: O...
# 33              Do We Still Need to Design Databases?
# 34  Eliminate Application Downtime with Oracle Dat...
# 35  Encrypt Your Crown Jewels and Manage Keys Effi...
# 36  Enhancing Oracle Fusion Applications Security ...
# 37  Expose Enterprise Integration Services as Cust...
# 38  Filter Big Data Streams Easily Using Java Streams
# 39                      Finally: DevOps for Databases
# 4   An Overview of Oracle Approvals Management Eng...
# 40  Five Inexpensive Tricks to Accelerate Oracle D...
# 41  Geo-Tagging, Geo-Enrichment, Geo-Fencing, and ...
# 42               Getting Started with Oracle and .NET
# 43  High Availability and Sharding Deep Dive with ...
# 44      How to Analyze Data Warehouse Data as a Graph
# 45                    How to Apply Policies to an API
# 46  How to Build a Decentralized Blockchain App wi...
# 47              How to Combine Data from Source Sites
# 48              How to Create a User-Managed Platform
# 49                     How to Create Web Applications
# 5   Application High Availability Best Practices a...
# 6            Application Integration on Oracle Cloud
# 7   Ask the Oracle Analytics Product Management an...
# 8   Autonomous Database Diagnostics Through Applie...
# 9   Autonomous Health for Oracle RAC Continuous Av...
#
#                         title_sort                      type
# 0   adatabaseproxyfortransparenthi  Product Training Session
# 1   adayinthelifeofarealworldperfo  Product Training Session
# 10  bestpracticesfordiagnosingandt  Product Training Session
# 11  bestpracticesforenterpriseappl  Product Training Session
# 12  bestpracticesforgoinghybridwit  Product Training Session
# 13  buildingfirewallsandloadbalanc  Product Training Session
# 14  buildingrealtimedatainwebappli  Product Training Session
# 15  buildmobileprogressivewebappso  Product Training Session
# 16  buildmultilingualdigitalassist  Product Training Session
# 17  chatwithoraclesaascloudappsusi  Product Training Session
# 18  configurediagnosetroubleshoots  Product Training Session
# 19  createaruleinoracleebusinessta  Product Training Session
# 2   adeepdiveintooraclesartificial  Product Training Session
# 20  createdatabaserestapisformobil  Product Training Session
# 21  creatingandmaintainingcommerce  Product Training Session
# 22  databaseconsolidationbestpract  Product Training Session
# 23  deepdiveanintroductiontoworkfl  Product Training Session
# 24  deepdiveapplicationintegration  Product Training Session
# 25  deepdivejavasecurecodingbestpr  Product Training Session
# 26  deepdiveoraclebigdataoraclebig  Product Training Session
# 27  deepdiveoracledatabase18cnewfe  Product Training Session
# 28  deepdiveoraclehcmcloudgettings  Product Training Session
# 29  developersdontbethepersonwhodi  Product Training Session
# 3   aninsidersguidetooracleautonom  Product Training Session
# 30  developimplementandmaintaindat  Product Training Session
# 31  developrobustenterpriseapplica  Product Training Session
# 32  diamondsmaybeforeverbutplatinu  Product Training Session
# 33  dowestillneedtodesigndatabases  Product Training Session
# 34  eliminateapplicationdowntimewi  Product Training Session
# 35  encryptyourcrownjewelsandmanag  Product Training Session
# 36  enhancingoraclefusionapplicati  Product Training Session
# 37  exposeenterpriseintegrationser  Product Training Session
# 38  filterbigdatastreamseasilyusin  Product Training Session
# 39       finallydevopsfordatabases  Product Training Session
# 4   anoverviewoforacleapprovalsman  Product Training Session
# 40  fiveinexpensivetrickstoacceler  Product Training Session
# 41  geotagginggeoenrichmentgeofenc  Product Training Session
# 42  gettingstartedwithoracleandnet  Product Training Session
# 43  highavailabilityandshardingdee  Product Training Session
# 44  howtoanalyzedatawarehousedataa  Product Training Session
# 45       howtoapplypoliciestoanapi  Product Training Session
# 46  howtobuildadecentralizedblockc  Product Training Session
# 47  howtocombinedatafromsourcesite  Product Training Session
# 48  howtocreateausermanagedplatfor  Product Training Session
# 49      howtocreatewebapplications  Product Training Session
# 5   applicationhighavailabilitybes  Product Training Session
# 6   applicationintegrationonoracle  Product Training Session
# 7   asktheoracleanalyticsproductma  Product Training Session
# 8   autonomousdatabasediagnosticst  Product Training Session
# 9   autonomoushealthfororacleracco  Product Training Session

# %%
#show nested array attributevalues for first record in Dataframe

ss['attributevalues'][0]
# Out:
# [{'attribute': 'Sessions by Experience Level',
#   'attribute_id': 'SessionsbyExperienceLevel',
#   'attributevalue_code': '1486682599762002N05j',
#   'attributevalue_id': '1486682599762002N05j',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 1.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1486682600237001NDhX',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Beginner',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Experience Level',
#   'attribute_id': 'SessionsbyExperienceLevel',
#   'attributevalue_code': '1486682599762003NG3N',
#   'attributevalue_id': '1486682599762003NG3N',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 2.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1486682600237002N7TO',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Intermediate',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Experience Level',
#   'attribute_id': 'SessionsbyExperienceLevel',
#   'attributevalue_code': '1486682712410001NgmB',
#   'attributevalue_id': '1486682712410001NgmB',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 3.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1486682712694001NyTi',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Advanced',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Track',
#   'attribute_id': 'Track',
#   'attributevalue_code': '150537435066001311wr',
#   'attributevalue_id': '150537435066001311wr',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 32.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '15053743521170121Lze',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '- Application Development',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Your Role',
#   'attribute_id': 'SessionsbyYourRole',
#   'attributevalue_code': '1517340027298003vDEK',
#   'attributevalue_id': '1517340027298003vDEK',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 2.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1517340030932002vsf0',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'DBA',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1517340176526002v4qA',
#   'attributevalue_id': '1517340176526002v4qA',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 1.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1517340180534001vTAC',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Enterprise',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1517340176526003vYnP',
#   'attributevalue_id': '1517340176526003vYnP',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 2.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1517340180534002vCwQ',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Growing Business',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1517340176526004vnmy',
#   'attributevalue_id': '1517340176526004vnmy',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 3.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1517340180534003vtge',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Start Up',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1518205606800001KWNx',
#   'attributevalue_id': '1518205606800001KWNx',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 4.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518205607074001KD3t',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '< $200M in annual revenue',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1518205606800002KHE2',
#   'attributevalue_id': '1518205606800002KHE2',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 5.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518205607074002K0BS',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '$201M - $500M in annual revenue',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1518205606800003K5KR',
#   'attributevalue_id': '1518205606800003K5KR',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 6.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518205607074003KeFF',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '$501M - $1B in annual revenue',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Company Market Size',
#   'attribute_id': 'SessionsbyCompanyMarketSize',
#   'attributevalue_code': '1518205606800004KbYk',
#   'attributevalue_id': '1518205606800004KbYk',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 7.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518205607074004KSH4',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Over $1B in annual revenue',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions by Your Role',
#   'attribute_id': 'SessionsbyYourRole',
#   'attributevalue_code': '1518463228663001KuV1',
#   'attributevalue_id': '1518463228663001KuV1',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 4.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518463228945001KqJE',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Developers',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Session Type',
#   'attribute_id': 'SessionType',
#   'attributevalue_code': '1518464344082001KHky',
#   'attributevalue_id': '1518464344082001KHky',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 26.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1518464344506001KUj0',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Product Training Session',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Oracle Cloud Platform',
#   'attribute_id': 'OracleCloudPlatform',
#   'attributevalue_code': '1519161685660003E73I',
#   'attributevalue_id': '1519161685660003E73I',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 7.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1519161690006002E78Z',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Cloud Platform',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Oracle Cloud Platform',
#   'attribute_id': 'OracleCloudPlatform',
#   'attributevalue_code': '1519161685660005Erra',
#   'attributevalue_id': '1519161685660005Erra',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 10.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1519161690006004ETQd',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Oracle Autonomous Database',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Oracle Cloud Platform',
#   'attribute_id': 'OracleCloudPlatform',
#   'attributevalue_code': '1519681984318001qkXu',
#   'attributevalue_id': '1519681984318001qkXu',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 2.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1519681984708001qBIN',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Application Development',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions By Topic',
#   'attribute_id': 'SessionsByTopic',
#   'attributevalue_code': '1527109815598010GJkW',
#   'attributevalue_id': '1527109815598010GJkW',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 3.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1527109821236009GhOk',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'The Data Explosion',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Sessions By Role',
#   'attribute_id': 'SessionsByRole',
#   'attributevalue_code': '1527706011542003XBOa',
#   'attributevalue_id': '1527706011542003XBOa',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 3.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1527706017371002XIVt',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'DBA',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Track',
#   'attribute_id': 'Track',
#   'attributevalue_code': '15373831503110202Gae',
#   'attributevalue_id': '15373831503110202Gae',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 1.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '153738315099002022zx',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Oracle Cloud Platform',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Track',
#   'attribute_id': 'Track',
#   'attributevalue_code': '1537383150311025240Q',
#   'attributevalue_id': '1537383150311025240Q',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 3.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '15373831509900252p9X',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '- Cloud Platform',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Track',
#   'attribute_id': 'Track',
#   'attributevalue_code': '15373831503110262yiA',
#   'attributevalue_id': '15373831503110262yiA',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 4.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '153738315099002627Iu',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '- Oracle Autonomous Database',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Event',
#   'attribute_id': 'Event',
#   'attributevalue_code': 'openworld',
#   'attributevalue_id': 'openworld',
#   'dataForm': '1503936308L8ef50df64',
#   'displayorder': 4.0,
#   'published': 1.0,
#   'rf_attributevalue_id': '1459962405839002bE2x',
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Oracle OpenWorld',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Time',
#   'attribute_id': 'DayTime',
#   'attributevalue_id': '20181024t11',
#   'dataForm': 'default',
#   'published': 1.0,
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': '11:00 a.m. Wednesday, Oct 24',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True},
#  {'attribute': 'Day',
#   'attribute_id': 'Day',
#   'attributevalue_id': '20181024',
#   'dataForm': 'default',
#   'published': 1.0,
#   'scheduleAccess': ['1533141196635001EZdJ', '1533143193464001uQsQ'],
#   'value': 'Wednesday, Oct 24',
#   'viewAccess': ['1533140082245001une2',
#    '1533141196635001EZdJ',
#    '1533143193464001uQsQ',
#    '1533146325902001u9v6'],
#   'viewAccessPublic': True}]

# %%
#show nested array participants for first record in Dataframe

ss['participants'][0]
ss['files'][0]
# Out:
# [{'fileId': '1540594881063001PjdE',
#   'filename': 'TRN4070_A-Database-Proxy-for-Transparent-High-Availability-Performance-Routing-and-Security.pdf',
#   'url': 'https://static.rainfocus.com/oracle/oow18/sess/1523650128750001VI1i/PF/TRN4070_A-Database-Proxy-for-Transparent-High-Availability-Performance-Routing-and-Security_1540594881049001PwHW.pdf',
#   'viewFileAccess': []}]

# %% [markdown]
# # Enriching the data
#
# Some of the enrichments that would be useful:
#     * set a flag at session level to indicate whether the session is an Oracle session (with Oracle staff among the speakers- speaker has Oracle in companyName attribute)
#     * set a flag at session level to indicate whether a file has been uploaded for the session
#     * set a flag at session level to indicate whether one of the speakers has Java Rockstar, Java Champion, Developer Champion/Groundbreaker Ambassador, ACE or ACE Director
#     * set attribute level (based on attributevalues array) - beginner, all, ...
#     * derive track(s?) from attributevalues array (where attribute_id=Track or attribute_id=CodeOneTracks  )
#     * set attribute with number of speakers on session
#     * set list with roles or set flag for role specific attributes (developer, dba, ...)
#
#
# Additionally, using a list of companies that sponsor OOW or CodeOne, set a flag on sessions that are presented by a speaker from one of the sponsors

# %%
#function to derive Oracle flag from participants
def oracle_speaker(session):
      result = "N"
      # loop over speakers; if for any of them, companyName contains the word Oracle, the result =Y  
      for x in session["participants"][:]:
        if ("oracle" in x['companyName'].lower()):
          result='Y'
      return result

# %%
#function to derive file flag from files
def file_flag(session):
      result = "N"
      if (pd.notnull(session["files"])):
          # loop over files; if any exist, then result = Y
          for x in session["files"][:]:
            if (x['fileId']):
              result='Y'
      return result

# %%
#set oracle_speaker flag
#apply function oracle_speaker to every row in the data frame to derive values for the new column oracle_speaker
ss['oracle_speaker'] = ss.apply(oracle_speaker, axis=1)

#set file_flag
#apply function file_flag to every row in the data frame to derive values for the new column file_flag
ss['file_flag'] = ss.apply(file_flag, axis=1)

#show sessions 
ss
# Out:
#                                              abstract  \
# 0   What if you could benefit from new database qu...
# 1   How does a real-world performance engineer int...
# 10  Understand the tools and techniques available ...
# 11  This session covers the best practices for per...
# 12  Should you refresh your current x86 hardware a...
# 13  Oracle Linux 7 offers the ability to natively ...
# 14  Real-time data is an increasingly popular topi...
# 15  Enterprises need to rapidly react to the chang...
# 16  Digital assistant and chatbot support for any ...
# 17  Do you wish Oracle Digital Assistant could ask...
# 18  In this session learn how to implement and use...
# 19  In this session learn how to set up a simple r...
# 2   This session takes a deep dive into how the Or...
# 20  In this session learn how to shape enterprise ...
# 21  The word “integration” has always conjured up ...
# 22  Consolidating databases requires configuring t...
# 23  This four-hour session will provide an overvie...
# 24  In this four-hour session learn how to meet yo...
# 25  This four-hour session covers secure coding be...
# 26  In this four-hour session learn about Oracle B...
# 27  In this session take a deep-dive into the late...
# 28  In this four-hour session learn how to use the...
# 29  Developers are under increasing  pressure to d...
# 3   Who says setting up and operating mission crit...
# 30  RESTful web services are gaining popularity be...
# 31  This session covers how to use Lambda Expressi...
# 32  Take advantage of the free SaaS application tr...
# 33  Hardware is cheap, the cloud is here, and reso...
# 34  Oracle Database brings unprecedented high avai...
# 35  Encrypting sensitive data has become a must in...
# 36  Integrating Oracle Fusion Applications such as...
# 37  This session explores how to quickly add a RES...
# 38  In this session learn how to filter, compute, ...
# 39  DevOps has become a common practice in the IT ...
# 4   Oracle Approvals Management is a highly extens...
# 40  In this session learn how to unlock even more ...
# 41  Oracle technologies make it easy to include lo...
# 42  How do you get started using Visual Studio to ...
# 43  Do you need global availability and scalabilit...
# 44  In this session gain new insights into your an...
# 45  In this session learn how to apply policies to...
# 46  During this deep-dive session learn how to bui...
# 47  In this session learn how to combine data from...
# 48  In this session learn how to create a user-man...
# 49  In this session learn how to create a web appl...
# 5   Make your applications run without interruptio...
# 6   In this session learn how to meet your applica...
# 7   In this session join development and product m...
# 8   In this session learn how to enable the autono...
# 9   In this session learn about the latest autonom...
#
#                                       attributevalues     code  \
# 0   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4070
# 1   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4026
# 10  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4567
# 11  [{'value': 'Product Training Session', 'attrib...  TRN6620
# 12  [{'value': 'Product Training Session', 'attrib...  TRN4782
# 13  [{'value': 'Intermediate', 'attributevalue_id'...  TRN1795
# 14  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4081
# 15  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5774
# 16  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5777
# 17  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5792
# 18  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4568
# 19  [{'value': 'Product Training Session', 'attrib...  TRN6615
# 2   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4631
# 20  [{'value': 'Product Training Session', 'attrib...  TRN6616
# 21  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6154
# 22  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5157
# 23  [{'value': 'Product Training Session', 'attrib...  TRN6461
# 24  [{'value': '- Integration', 'attributevalue_id...  TRN6458
# 25  [{'value': 'Product Training Session', 'attrib...  TRN6463
# 26  [{'value': 'Product Training Session', 'attrib...  TRN6460
# 27  [{'value': 'Product Training Session', 'attrib...  TRN6462
# 28  [{'value': 'Product Training Session', 'attrib...  TRN6459
# 29  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4096
# 3   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN3979
# 30  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6451
# 31  [{'value': 'Product Training Session', 'attrib...  TRN6619
# 32  [{'value': 'Product Training Session', 'attrib...  TRN6356
# 33  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1743
# 34  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4086
# 35  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4106
# 36  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6963
# 37  [{'value': 'Product Training Session', 'attrib...  TRN6618
# 38  [{'value': 'Product Training Session', 'attrib...  TRN6617
# 39  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4088
# 4   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6446
# 40  [{'value': 'Advanced', 'attributevalue_id': '1...  TRN4499
# 41  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4095
# 42  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4082
# 43  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4032
# 44  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4099
# 45  [{'value': 'Product Training Session', 'attrib...  TRN6511
# 46  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1918
# 47  [{'value': 'Product Training Session', 'attrib...  TRN6520
# 48  [{'value': 'Product Training Session', 'attrib...  TRN6522
# 49  [{'value': 'Product Training Session', 'attrib...  TRN6516
# 5   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4078
# 6   [{'value': 'Product Training Session', 'attrib...  TRN6352
# 7   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6168
# 8   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4162
# 9   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4163
#
#                event eventCode  \
# 0   Oracle OpenWorld     oow18
# 1   Oracle OpenWorld     oow18
# 10  Oracle OpenWorld     oow18
# 11  Oracle OpenWorld     oow18
# 12  Oracle OpenWorld     oow18
# 13  Oracle OpenWorld     oow18
# 14  Oracle OpenWorld     oow18
# 15  Oracle OpenWorld     oow18
# 16  Oracle OpenWorld     oow18
# 17  Oracle OpenWorld     oow18
# 18  Oracle OpenWorld     oow18
# 19  Oracle OpenWorld     oow18
# 2   Oracle OpenWorld     oow18
# 20  Oracle OpenWorld     oow18
# 21  Oracle OpenWorld     oow18
# 22  Oracle OpenWorld     oow18
# 23  Oracle OpenWorld     oow18
# 24  Oracle OpenWorld     oow18
# 25  Oracle OpenWorld     oow18
# 26  Oracle OpenWorld     oow18
# 27  Oracle OpenWorld     oow18
# 28  Oracle OpenWorld     oow18
# 29  Oracle OpenWorld     oow18
# 3   Oracle OpenWorld     oow18
# 30  Oracle OpenWorld     oow18
# 31  Oracle OpenWorld     oow18
# 32  Oracle OpenWorld     oow18
# 33  Oracle OpenWorld     oow18
# 34  Oracle OpenWorld     oow18
# 35  Oracle OpenWorld     oow18
# 36  Oracle OpenWorld     oow18
# 37  Oracle OpenWorld     oow18
# 38  Oracle OpenWorld     oow18
# 39  Oracle OpenWorld     oow18
# 4   Oracle OpenWorld     oow18
# 40  Oracle OpenWorld     oow18
# 41  Oracle OpenWorld     oow18
# 42  Oracle OpenWorld     oow18
# 43  Oracle OpenWorld     oow18
# 44  Oracle OpenWorld     oow18
# 45  Oracle OpenWorld     oow18
# 46  Oracle OpenWorld     oow18
# 47  Oracle OpenWorld     oow18
# 48  Oracle OpenWorld     oow18
# 49  Oracle OpenWorld     oow18
# 5   Oracle OpenWorld     oow18
# 6   Oracle OpenWorld     oow18
# 7   Oracle OpenWorld     oow18
# 8   Oracle OpenWorld     oow18
# 9   Oracle OpenWorld     oow18
#
#                                                 files  length  \
# 0   [{'fileId': '1540594881063001PjdE', 'filename'...      45
# 1   [{'fileId': '1540053090863001JeFM', 'filename'...      45
# 10  [{'fileId': '1539988618000001VcCe', 'filename'...      45
# 11                                               None      20
# 12  [{'fileId': '1541718307822001nnE5', 'filename'...      45
# 13  [{'fileId': '1540823655456001S2yU', 'filename'...      45
# 14  [{'fileId': '1540586960748001awpB', 'filename'...      45
# 15  [{'fileId': '1540498947195001Q0Ng', 'filename'...      45
# 16  [{'fileId': '1540304567821001vNsN', 'filename'...      45
# 17  [{'fileId': '1542151051287001R7i9', 'filename'...      45
# 18  [{'fileId': '1540476654486001kh1V', 'filename'...      45
# 19  [{'fileId': '1539815634830001z0Yt', 'filename'...      20
# 2                                                None      45
# 20  [{'fileId': '1540138774225001QP4j', 'filename'...      20
# 21                                               None      45
# 22  [{'fileId': '1542289822562001Wyh2', 'filename'...      45
# 23  [{'fileId': '1540267572704001DPfY', 'filename'...     240
# 24  [{'fileId': '1539983113140001dUD6', 'filename'...     240
# 25                                               None     240
# 26  [{'fileId': '1540527681659001JDvx', 'filename'...     240
# 27  [{'fileId': '1540231956194001DVjv', 'filename'...     240
# 28  [{'fileId': '1539725236806001lwQU', 'filename'...     240
# 29  [{'fileId': '1540795935251001S515', 'filename'...      45
# 3   [{'fileId': '1540586876838001Ph9B', 'filename'...      45
# 30  [{'fileId': '15401387571180016fMd', 'filename'...      45
# 31                                               None      20
# 32                                               None      45
# 33  [{'fileId': '1540792881998001P1gG', 'filename'...      45
# 34  [{'fileId': '1540524901214001DeiN', 'filename'...      45
# 35  [{'fileId': '1540946073032001t4Xq', 'filename'...      45
# 36  [{'fileId': '1540835441272001sbxy', 'filename'...      45
# 37  [{'fileId': '1540138803558001Jt4Z', 'filename'...      20
# 38  [{'fileId': '1540138790214001vcVs', 'filename'...      20
# 39                                               None      45
# 4   [{'fileId': '1539815058569001lvIK', 'filename'...      45
# 40  [{'fileId': '15414557470710017n4B', 'filename'...      45
# 41  [{'fileId': '1540906576250001scXJ', 'filename'...      45
# 42  [{'fileId': '1543251169356001Rr8J', 'filename'...      45
# 43  [{'fileId': '1541456703248001Bmgl', 'filename'...      45
# 44  [{'fileId': '1540993657058001xLIc', 'filename'...      45
# 45  [{'fileId': '1539983314113001Ddd3', 'filename'...      20
# 46  [{'fileId': '1540133033796001JEIg', 'filename'...      45
# 47  [{'fileId': '1540221835507001QL6R', 'filename'...      20
# 48  [{'fileId': '1540220944732001JNkX', 'filename'...      20
# 49  [{'fileId': '1539983570031001QKVJ', 'filename'...      20
# 5   [{'fileId': '1540591572080001fr6Q', 'filename'...      45
# 6   [{'fileId': '1539979883463001Voaf', 'filename'...      45
# 7                                                None      45
# 8   [{'fileId': '1541467971650001UYFt', 'filename'...      45
# 9   [{'fileId': '1540528741382001Q6i3', 'filename'...      45
#
#                                          participants  \
# 0   [{'speakerId': '14574694377280015QNA_150393630...
# 1   [{'speakerId': '145746969078000151fg_150393630...
# 10  [{'speakerId': '1468532302119001DtNf_150393630...
# 11  [{'speakerId': '1470698803884001CfwZ_150393630...
# 12  [{'speakerId': '14574694661200015oeh_150393630...
# 13  [{'speakerId': '1521580422142001cXpX_150393630...
# 14  [{'speakerId': '14574694955970015EaV_150393630...
# 15  [{'speakerId': '14574696964400015ReA_150393630...
# 16  [{'speakerId': '1462125550493001D3Xz_150393630...
# 17  [{'speakerId': '1515103283372001FgzI_150393630...
# 18  [{'speakerId': '1472560122691001TA73_150393630...
# 19  [{'speakerId': '1533151159169001TlLV_150393630...
# 2   [{'speakerId': '15315177009490016aEX_150393630...
# 20  [{'speakerId': '1533153526686001aze0_150393630...
# 21  [{'speakerId': '14574697717300035Hxm_150393630...
# 22  [{'speakerId': '14574694775980015e0D_150393630...
# 23  [{'speakerId': '1467230960339001h4Nj_150393630...
# 24  [{'speakerId': '1500580326390001qTtd_150393630...
# 25  [{'speakerId': '1470698803884001CfwZ_150393630...
# 26  [{'speakerId': '14664511836130012Qxc_150393630...
# 27  [{'speakerId': '1500578268510001KsST_150393630...
# 28  [{'speakerId': '1467230528322001hGg0_150393630...
# 29  [{'speakerId': '14574694988420015Jbn_150393630...
# 3   [{'speakerId': '14574694525770015tTj_150393630...
# 30  [{'speakerId': '1533153526686001aze0_150393630...
# 31  [{'speakerId': '1470698803884001CfwZ_150393630...
# 32  [{'speakerId': '14574696120130015JlG_150393630...
# 33  [{'speakerId': '145746943683700158HC_150393630...
# 34  [{'speakerId': '14574694354950015iFv_150393630...
# 35  [{'speakerId': '14574696616110015fCp_150393630...
# 36  [{'speakerId': '14574694733280025bh3_150393630...
# 37  [{'speakerId': '1533153526686001aze0_150393630...
# 38  [{'speakerId': '1533153526686001aze0_150393630...
# 39  [{'speakerId': '14574694370360025gMe_150393630...
# 4   [{'speakerId': '1533151159169001TlLV_150393630...
# 40  [{'speakerId': '14574697206660015bfV_150393630...
# 41  [{'speakerId': '14574694762980015eve_150393630...
# 42  [{'speakerId': '14574694748550015JRe_150393630...
# 43  [{'speakerId': '14574695098990015wUk_150393630...
# 44  [{'speakerId': '14574694711340015m5k_150393630...
# 45  [{'speakerId': '1500580326390001qTtd_150393630...
# 46  [{'speakerId': '145746944760700159kb_150393630...
# 47  [{'speakerId': '14574694422520015XTf_150393630...
# 48  [{'speakerId': '14574694422520015XTf_150393630...
# 49  [{'speakerId': '1500580326390001qTtd_150393630...
# 5   [{'speakerId': '14574694639010015kGi_150393630...
# 6   [{'speakerId': '1500580326390001qTtd_150393630...
# 7   [{'speakerId': '14574694685180025oHC_150393630...
# 8   [{'speakerId': '14574694459920025cpR_150393630...
# 9   [{'speakerId': '14574695070120015ey6_150393630...
#
#                                                 times  \
# 0   [{'sessionTimeID': '1532616475210001usPa', 'se...
# 1   [{'sessionTimeID': '1531945554973001z4Hi', 'se...
# 10  [{'sessionTimeID': '15352384203600012G04', 'se...
# 11  [{'sessionTimeID': '1538112369718001MoR2', 'se...
# 12  [{'sessionTimeID': '1535044864680001SZQw', 'se...
# 13  [{'sessionTimeID': '1535047180566001tTGP', 'se...
# 14  [{'sessionTimeID': '1531854081960001fkV5', 'se...
# 15  [{'sessionTimeID': '1533759384227001uIZh', 'se...
# 16  [{'sessionTimeID': '1533759287589001DyMn', 'se...
# 17  [{'sessionTimeID': '1533797930591001DtuZ', 'se...
# 18  [{'sessionTimeID': '1534548822332001jDNv', 'se...
# 19  [{'sessionTimeID': '15381125187210018fbH', 'se...
# 2   [{'sessionTimeID': '1535697245338001x3yZ', 'se...
# 20  [{'sessionTimeID': '1538112267267001PV2e', 'se...
# 21  [{'sessionTimeID': '1536195528781001YHbb', 'se...
# 22  [{'sessionTimeID': '1532734468296001S4ra', 'se...
# 23  [{'sessionTimeID': '1537150614045001Fc1v', 'se...
# 24  [{'sessionTimeID': '1537255427664001P8OT', 'se...
# 25  [{'sessionTimeID': '1537150687958001eoZ7', 'se...
# 26  [{'sessionTimeID': '1537150650927001PHnW', 'se...
# 27  [{'sessionTimeID': '1537150669415001Foxx', 'se...
# 28  [{'sessionTimeID': '1537150593997001PXcV', 'se...
# 29  [{'sessionTimeID': '1531854038107001ankr', 'se...
# 3   [{'sessionTimeID': '1531859121810001TdYU', 'se...
# 30  [{'sessionTimeID': '1535316983456001BNUt', 'se...
# 31  [{'sessionTimeID': '1538112283675001MFof', 'se...
# 32  [{'sessionTimeID': '15352234095720011o4W', 'se...
# 33  [{'sessionTimeID': '1535170950479001Bqi3', 'se...
# 34  [{'sessionTimeID': '1531849969460001fzY3', 'se...
# 35  [{'sessionTimeID': '1531769844473001acP5', 'se...
# 36  [{'sessionTimeID': '1539627763346001Nol6', 'se...
# 37  [{'sessionTimeID': '1538112532706001Pb5D', 'se...
# 38  [{'sessionTimeID': '1538112427579001MNeY', 'se...
# 39  [{'sessionTimeID': '1531848290901001fiBN', 'se...
# 4   [{'sessionTimeID': '15353154410710012PiP', 'se...
# 40  [{'sessionTimeID': '1535046699651001SvIb', 'se...
# 41  [{'sessionTimeID': '1531946578948001zDRs', 'se...
# 42  [{'sessionTimeID': '1531849529027001TJcf', 'se...
# 43  [{'sessionTimeID': '15320334995950015aXk', 'se...
# 44  [{'sessionTimeID': '1531945644126001zzma', 'se...
# 45  [{'sessionTimeID': '15381123375010018r1z', 'se...
# 46  [{'sessionTimeID': '1533758776080001MDuW', 'se...
# 47  [{'sessionTimeID': '1538112351906001PAkt', 'se...
# 48  [{'sessionTimeID': '1538112737368001PGzW', 'se...
# 49  [{'sessionTimeID': '1538112695700001MkPC', 'se...
# 5   [{'sessionTimeID': '1531853834216001TVkZ', 'se...
# 6   [{'sessionTimeID': '1535317184544001BYVj', 'se...
# 7   [{'sessionTimeID': '15343996004640012QHh', 'se...
# 8   [{'sessionTimeID': '1531861316059001fOyC', 'se...
# 9   [{'sessionTimeID': '1531861261596001T69W', 'se...
#
#                                                 title  \
# 0   A Database Proxy for Transparent High Availabi...
# 1   A Day in the Life of a Real-World Performance ...
# 10  Best Practices for Diagnosing and Troubleshoot...
# 11  Best Practices for Enterprise Application Perf...
# 12  Best Practices for Going Hybrid with Oracle's ...
# 13  Building Firewalls and Load Balancers on Oracl...
# 14  Building Real-Time Data in Web Applications wi...
# 15  Build Mobile/Progressive Web Apps: Oracle Visu...
# 16  Build Multilingual Digital Assistants/Chatbots...
# 17  Chat With Oracle SaaS Cloud Apps using Your Or...
# 18  Configure, Diagnose, Troubleshoot Security Ass...
# 19  Create a Rule in Oracle E-Business Tax to Dete...
# 2   A Deep Dive into Oracle's Artificial Intellige...
# 20  Create Database REST APIs for Mobile Apps Usin...
# 21  Creating and Maintaining Commerce Integrations...
# 22  Database Consolidation: Best Practices for Suc...
# 23  Deep Dive: An Introduction to Workflow Approva...
# 24  Deep Dive: Application Integration on Oracle C...
# 25       Deep Dive: Java Secure Coding Best Practices
# 26  Deep Dive: Oracle Big Data/Oracle Big Data Clo...
# 27  Deep Dive: Oracle Database 18c New Features: C...
# 28  Deep Dive: Oracle HCM Cloud: Getting Started w...
# 29  Developers: Don’t Be the Person Who Discombobu...
# 3   An Insider’s Guide to Oracle Autonomous Transa...
# 30  Develop, Implement, and Maintain Database REST...
# 31  Develop Robust Enterprise Applications with Ja...
# 32  Diamonds May Be Forever but Platinum Is Now: O...
# 33              Do We Still Need to Design Databases?
# 34  Eliminate Application Downtime with Oracle Dat...
# 35  Encrypt Your Crown Jewels and Manage Keys Effi...
# 36  Enhancing Oracle Fusion Applications Security ...
# 37  Expose Enterprise Integration Services as Cust...
# 38  Filter Big Data Streams Easily Using Java Streams
# 39                      Finally: DevOps for Databases
# 4   An Overview of Oracle Approvals Management Eng...
# 40  Five Inexpensive Tricks to Accelerate Oracle D...
# 41  Geo-Tagging, Geo-Enrichment, Geo-Fencing, and ...
# 42               Getting Started with Oracle and .NET
# 43  High Availability and Sharding Deep Dive with ...
# 44      How to Analyze Data Warehouse Data as a Graph
# 45                    How to Apply Policies to an API
# 46  How to Build a Decentralized Blockchain App wi...
# 47              How to Combine Data from Source Sites
# 48              How to Create a User-Managed Platform
# 49                     How to Create Web Applications
# 5   Application High Availability Best Practices a...
# 6            Application Integration on Oracle Cloud
# 7   Ask the Oracle Analytics Product Management an...
# 8   Autonomous Database Diagnostics Through Applie...
# 9   Autonomous Health for Oracle RAC Continuous Av...
#
#                         title_sort                      type oracle_speaker  \
# 0   adatabaseproxyfortransparenthi  Product Training Session              Y
# 1   adayinthelifeofarealworldperfo  Product Training Session              Y
# 10  bestpracticesfordiagnosingandt  Product Training Session              Y
# 11  bestpracticesforenterpriseappl  Product Training Session              Y
# 12  bestpracticesforgoinghybridwit  Product Training Session              Y
# 13  buildingfirewallsandloadbalanc  Product Training Session              Y
# 14  buildingrealtimedatainwebappli  Product Training Session              Y
# 15  buildmobileprogressivewebappso  Product Training Session              Y
# 16  buildmultilingualdigitalassist  Product Training Session              Y
# 17  chatwithoraclesaascloudappsusi  Product Training Session              Y
# 18  configurediagnosetroubleshoots  Product Training Session              Y
# 19  createaruleinoracleebusinessta  Product Training Session              Y
# 2   adeepdiveintooraclesartificial  Product Training Session              Y
# 20  createdatabaserestapisformobil  Product Training Session              Y
# 21  creatingandmaintainingcommerce  Product Training Session              Y
# 22  databaseconsolidationbestpract  Product Training Session              Y
# 23  deepdiveanintroductiontoworkfl  Product Training Session              Y
# 24  deepdiveapplicationintegration  Product Training Session              Y
# 25  deepdivejavasecurecodingbestpr  Product Training Session              Y
# 26  deepdiveoraclebigdataoraclebig  Product Training Session              Y
# 27  deepdiveoracledatabase18cnewfe  Product Training Session              Y
# 28  deepdiveoraclehcmcloudgettings  Product Training Session              Y
# 29  developersdontbethepersonwhodi  Product Training Session              Y
# 3   aninsidersguidetooracleautonom  Product Training Session              Y
# 30  developimplementandmaintaindat  Product Training Session              Y
# 31  developrobustenterpriseapplica  Product Training Session              Y
# 32  diamondsmaybeforeverbutplatinu  Product Training Session              Y
# 33  dowestillneedtodesigndatabases  Product Training Session              N
# 34  eliminateapplicationdowntimewi  Product Training Session              Y
# 35  encryptyourcrownjewelsandmanag  Product Training Session              Y
# 36  enhancingoraclefusionapplicati  Product Training Session              Y
# 37  exposeenterpriseintegrationser  Product Training Session              Y
# 38  filterbigdatastreamseasilyusin  Product Training Session              Y
# 39       finallydevopsfordatabases  Product Training Session              Y
# 4   anoverviewoforacleapprovalsman  Product Training Session              Y
# 40  fiveinexpensivetrickstoacceler  Product Training Session              Y
# 41  geotagginggeoenrichmentgeofenc  Product Training Session              Y
# 42  gettingstartedwithoracleandnet  Product Training Session              Y
# 43  highavailabilityandshardingdee  Product Training Session              Y
# 44  howtoanalyzedatawarehousedataa  Product Training Session              Y
# 45       howtoapplypoliciestoanapi  Product Training Session              Y
# 46  howtobuildadecentralizedblockc  Product Training Session              N
# 47  howtocombinedatafromsourcesite  Product Training Session              Y
# 48  howtocreateausermanagedplatfor  Product Training Session              Y
# 49      howtocreatewebapplications  Product Training Session              Y
# 5   applicationhighavailabilitybes  Product Training Session              Y
# 6   applicationintegrationonoracle  Product Training Session              Y
# 7   asktheoracleanalyticsproductma  Product Training Session              Y
# 8   autonomousdatabasediagnosticst  Product Training Session              Y
# 9   autonomoushealthfororacleracco  Product Training Session              Y
#
#    file_flag
# 0          Y
# 1          Y
# 10         Y
# 11         N
# 12         Y
# 13         Y
# 14         Y
# 15         Y
# 16         Y
# 17         Y
# 18         Y
# 19         Y
# 2          N
# 20         Y
# 21         N
# 22         Y
# 23         Y
# 24         Y
# 25         N
# 26         Y
# 27         Y
# 28         Y
# 29         Y
# 3          Y
# 30         Y
# 31         N
# 32         N
# 33         Y
# 34         Y
# 35         Y
# 36         Y
# 37         Y
# 38         Y
# 39         N
# 4          Y
# 40         Y
# 41         Y
# 42         Y
# 43         Y
# 44         Y
# 45         Y
# 46         Y
# 47         Y
# 48         Y
# 49         Y
# 5          Y
# 6          Y
# 7          N
# 8          Y
# 9          Y

# %%
#function to derive designation flag from speakers
# values for designation: JavaOne Rockstar, Oracle ACE Director, Oracle Java Champion, Groundbreaker Ambassador, 
def speaker_designation(session, designation):
      result = "N"
      # loop over speakers and their attributevalues; if any exist with attribute_id == specialdesignations and value == JavaOne Rockstar
      for x in session["participants"][:]:
          if "attributevalues" in x: 
              for y in x["attributevalues"][:]:
                if "attribute_id" in y: 
                    if y["attribute_id"]=="specialdesignations":
                        if y["value"]== designation:
                            result="Y"
                        print (y["value"], " == ",result,"  ",designation)
      return result

# %%
#set flags for designations
designations = ['JavaOne Rockstar', 'Oracle ACE Director', 'Oracle Java Champion', 'Groundbreaker Ambassador']
for d in designations:
   ss[d] = ss.apply(speaker_designation, args=(d,), axis=1) 

ss
# Out:
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle ACE  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle ACE  ==  N    JavaOne Rockstar
# Oracle ACE  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle ACE  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# JavaOne Rockstar  ==  Y    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle ACE Director  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle ACE  ==  N    JavaOne Rockstar
# Oracle ACE Associate  ==  N    JavaOne Rockstar
# Groundbreaker Ambassador  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    JavaOne Rockstar
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle ACE  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle ACE  ==  N    Oracle ACE Director
# Oracle ACE  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle ACE  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# JavaOne Rockstar  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle ACE Director  ==  Y    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle ACE  ==  N    Oracle ACE Director
# Oracle ACE Associate  ==  N    Oracle ACE Director
# Groundbreaker Ambassador  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle ACE Director
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle ACE  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle ACE  ==  N    Oracle Java Champion
# Oracle ACE  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle ACE  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# JavaOne Rockstar  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle ACE Director  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle ACE  ==  N    Oracle Java Champion
# Oracle ACE Associate  ==  N    Oracle Java Champion
# Groundbreaker Ambassador  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Oracle Java Champion
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle ACE  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle ACE  ==  N    Groundbreaker Ambassador
# Oracle ACE  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle ACE  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# JavaOne Rockstar  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle ACE Director  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle ACE  ==  N    Groundbreaker Ambassador
# Oracle ACE Associate  ==  N    Groundbreaker Ambassador
# Groundbreaker Ambassador  ==  Y    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
# Oracle Certified  ==  N    Groundbreaker Ambassador
#                                              abstract  \
# 0   What if you could benefit from new database qu...
# 1   How does a real-world performance engineer int...
# 10  Understand the tools and techniques available ...
# 11  This session covers the best practices for per...
# 12  Should you refresh your current x86 hardware a...
# 13  Oracle Linux 7 offers the ability to natively ...
# 14  Real-time data is an increasingly popular topi...
# 15  Enterprises need to rapidly react to the chang...
# 16  Digital assistant and chatbot support for any ...
# 17  Do you wish Oracle Digital Assistant could ask...
# 18  In this session learn how to implement and use...
# 19  In this session learn how to set up a simple r...
# 2   This session takes a deep dive into how the Or...
# 20  In this session learn how to shape enterprise ...
# 21  The word “integration” has always conjured up ...
# 22  Consolidating databases requires configuring t...
# 23  This four-hour session will provide an overvie...
# 24  In this four-hour session learn how to meet yo...
# 25  This four-hour session covers secure coding be...
# 26  In this four-hour session learn about Oracle B...
# 27  In this session take a deep-dive into the late...
# 28  In this four-hour session learn how to use the...
# 29  Developers are under increasing  pressure to d...
# 3   Who says setting up and operating mission crit...
# 30  RESTful web services are gaining popularity be...
# 31  This session covers how to use Lambda Expressi...
# 32  Take advantage of the free SaaS application tr...
# 33  Hardware is cheap, the cloud is here, and reso...
# 34  Oracle Database brings unprecedented high avai...
# 35  Encrypting sensitive data has become a must in...
# 36  Integrating Oracle Fusion Applications such as...
# 37  This session explores how to quickly add a RES...
# 38  In this session learn how to filter, compute, ...
# 39  DevOps has become a common practice in the IT ...
# 4   Oracle Approvals Management is a highly extens...
# 40  In this session learn how to unlock even more ...
# 41  Oracle technologies make it easy to include lo...
# 42  How do you get started using Visual Studio to ...
# 43  Do you need global availability and scalabilit...
# 44  In this session gain new insights into your an...
# 45  In this session learn how to apply policies to...
# 46  During this deep-dive session learn how to bui...
# 47  In this session learn how to combine data from...
# 48  In this session learn how to create a user-man...
# 49  In this session learn how to create a web appl...
# 5   Make your applications run without interruptio...
# 6   In this session learn how to meet your applica...
# 7   In this session join development and product m...
# 8   In this session learn how to enable the autono...
# 9   In this session learn about the latest autonom...
#
#                                       attributevalues     code  \
# 0   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4070
# 1   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4026
# 10  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4567
# 11  [{'value': 'Product Training Session', 'attrib...  TRN6620
# 12  [{'value': 'Product Training Session', 'attrib...  TRN4782
# 13  [{'value': 'Intermediate', 'attributevalue_id'...  TRN1795
# 14  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4081
# 15  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5774
# 16  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5777
# 17  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5792
# 18  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4568
# 19  [{'value': 'Product Training Session', 'attrib...  TRN6615
# 2   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4631
# 20  [{'value': 'Product Training Session', 'attrib...  TRN6616
# 21  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6154
# 22  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5157
# 23  [{'value': 'Product Training Session', 'attrib...  TRN6461
# 24  [{'value': '- Integration', 'attributevalue_id...  TRN6458
# 25  [{'value': 'Product Training Session', 'attrib...  TRN6463
# 26  [{'value': 'Product Training Session', 'attrib...  TRN6460
# 27  [{'value': 'Product Training Session', 'attrib...  TRN6462
# 28  [{'value': 'Product Training Session', 'attrib...  TRN6459
# 29  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4096
# 3   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN3979
# 30  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6451
# 31  [{'value': 'Product Training Session', 'attrib...  TRN6619
# 32  [{'value': 'Product Training Session', 'attrib...  TRN6356
# 33  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1743
# 34  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4086
# 35  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4106
# 36  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6963
# 37  [{'value': 'Product Training Session', 'attrib...  TRN6618
# 38  [{'value': 'Product Training Session', 'attrib...  TRN6617
# 39  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4088
# 4   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6446
# 40  [{'value': 'Advanced', 'attributevalue_id': '1...  TRN4499
# 41  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4095
# 42  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4082
# 43  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4032
# 44  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4099
# 45  [{'value': 'Product Training Session', 'attrib...  TRN6511
# 46  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1918
# 47  [{'value': 'Product Training Session', 'attrib...  TRN6520
# 48  [{'value': 'Product Training Session', 'attrib...  TRN6522
# 49  [{'value': 'Product Training Session', 'attrib...  TRN6516
# 5   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4078
# 6   [{'value': 'Product Training Session', 'attrib...  TRN6352
# 7   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6168
# 8   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4162
# 9   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4163
#
#                event eventCode  \
# 0   Oracle OpenWorld     oow18
# 1   Oracle OpenWorld     oow18
# 10  Oracle OpenWorld     oow18
# 11  Oracle OpenWorld     oow18
# 12  Oracle OpenWorld     oow18
# 13  Oracle OpenWorld     oow18
# 14  Oracle OpenWorld     oow18
# 15  Oracle OpenWorld     oow18
# 16  Oracle OpenWorld     oow18
# 17  Oracle OpenWorld     oow18
# 18  Oracle OpenWorld     oow18
# 19  Oracle OpenWorld     oow18
# 2   Oracle OpenWorld     oow18
# 20  Oracle OpenWorld     oow18
# 21  Oracle OpenWorld     oow18
# 22  Oracle OpenWorld     oow18
# 23  Oracle OpenWorld     oow18
# 24  Oracle OpenWorld     oow18
# 25  Oracle OpenWorld     oow18
# 26  Oracle OpenWorld     oow18
# 27  Oracle OpenWorld     oow18
# 28  Oracle OpenWorld     oow18
# 29  Oracle OpenWorld     oow18
# 3   Oracle OpenWorld     oow18
# 30  Oracle OpenWorld     oow18
# 31  Oracle OpenWorld     oow18
# 32  Oracle OpenWorld     oow18
# 33  Oracle OpenWorld     oow18
# 34  Oracle OpenWorld     oow18
# 35  Oracle OpenWorld     oow18
# 36  Oracle OpenWorld     oow18
# 37  Oracle OpenWorld     oow18
# 38  Oracle OpenWorld     oow18
# 39  Oracle OpenWorld     oow18
# 4   Oracle OpenWorld     oow18
# 40  Oracle OpenWorld     oow18
# 41  Oracle OpenWorld     oow18
# 42  Oracle OpenWorld     oow18
# 43  Oracle OpenWorld     oow18
# 44  Oracle OpenWorld     oow18
# 45  Oracle OpenWorld     oow18
# 46  Oracle OpenWorld     oow18
# 47  Oracle OpenWorld     oow18
# 48  Oracle OpenWorld     oow18
# 49  Oracle OpenWorld     oow18
# 5   Oracle OpenWorld     oow18
# 6   Oracle OpenWorld     oow18
# 7   Oracle OpenWorld     oow18
# 8   Oracle OpenWorld     oow18
# 9   Oracle OpenWorld     oow18
#
#                                                 files  length  \
# 0   [{'fileId': '1540594881063001PjdE', 'filename'...      45
# 1   [{'fileId': '1540053090863001JeFM', 'filename'...      45
# 10  [{'fileId': '1539988618000001VcCe', 'filename'...      45
# 11                                               None      20
# 12  [{'fileId': '1541718307822001nnE5', 'filename'...      45
# 13  [{'fileId': '1540823655456001S2yU', 'filename'...      45
# 14  [{'fileId': '1540586960748001awpB', 'filename'...      45
# 15  [{'fileId': '1540498947195001Q0Ng', 'filename'...      45
# 16  [{'fileId': '1540304567821001vNsN', 'filename'...      45
# 17  [{'fileId': '1542151051287001R7i9', 'filename'...      45
# 18  [{'fileId': '1540476654486001kh1V', 'filename'...      45
# 19  [{'fileId': '1539815634830001z0Yt', 'filename'...      20
# 2                                                None      45
# 20  [{'fileId': '1540138774225001QP4j', 'filename'...      20
# 21                                               None      45
# 22  [{'fileId': '1542289822562001Wyh2', 'filename'...      45
# 23  [{'fileId': '1540267572704001DPfY', 'filename'...     240
# 24  [{'fileId': '1539983113140001dUD6', 'filename'...     240
# 25                                               None     240
# 26  [{'fileId': '1540527681659001JDvx', 'filename'...     240
# 27  [{'fileId': '1540231956194001DVjv', 'filename'...     240
# 28  [{'fileId': '1539725236806001lwQU', 'filename'...     240
# 29  [{'fileId': '1540795935251001S515', 'filename'...      45
# 3   [{'fileId': '1540586876838001Ph9B', 'filename'...      45
# 30  [{'fileId': '15401387571180016fMd', 'filename'...      45
# 31                                               None      20
# 32                                               None      45
# 33  [{'fileId': '1540792881998001P1gG', 'filename'...      45
# 34  [{'fileId': '1540524901214001DeiN', 'filename'...      45
# 35  [{'fileId': '1540946073032001t4Xq', 'filename'...      45
# 36  [{'fileId': '1540835441272001sbxy', 'filename'...      45
# 37  [{'fileId': '1540138803558001Jt4Z', 'filename'...      20
# 38  [{'fileId': '1540138790214001vcVs', 'filename'...      20
# 39                                               None      45
# 4   [{'fileId': '1539815058569001lvIK', 'filename'...      45
# 40  [{'fileId': '15414557470710017n4B', 'filename'...      45
# 41  [{'fileId': '1540906576250001scXJ', 'filename'...      45
# 42  [{'fileId': '1543251169356001Rr8J', 'filename'...      45
# 43  [{'fileId': '1541456703248001Bmgl', 'filename'...      45
# 44  [{'fileId': '1540993657058001xLIc', 'filename'...      45
# 45  [{'fileId': '1539983314113001Ddd3', 'filename'...      20
# 46  [{'fileId': '1540133033796001JEIg', 'filename'...      45
# 47  [{'fileId': '1540221835507001QL6R', 'filename'...      20
# 48  [{'fileId': '1540220944732001JNkX', 'filename'...      20
# 49  [{'fileId': '1539983570031001QKVJ', 'filename'...      20
# 5   [{'fileId': '1540591572080001fr6Q', 'filename'...      45
# 6   [{'fileId': '1539979883463001Voaf', 'filename'...      45
# 7                                                None      45
# 8   [{'fileId': '1541467971650001UYFt', 'filename'...      45
# 9   [{'fileId': '1540528741382001Q6i3', 'filename'...      45
#
#                                          participants  \
# 0   [{'speakerId': '14574694377280015QNA_150393630...
# 1   [{'speakerId': '145746969078000151fg_150393630...
# 10  [{'speakerId': '1468532302119001DtNf_150393630...
# 11  [{'speakerId': '1470698803884001CfwZ_150393630...
# 12  [{'speakerId': '14574694661200015oeh_150393630...
# 13  [{'speakerId': '1521580422142001cXpX_150393630...
# 14  [{'speakerId': '14574694955970015EaV_150393630...
# 15  [{'speakerId': '14574696964400015ReA_150393630...
# 16  [{'speakerId': '1462125550493001D3Xz_150393630...
# 17  [{'speakerId': '1515103283372001FgzI_150393630...
# 18  [{'speakerId': '1472560122691001TA73_150393630...
# 19  [{'speakerId': '1533151159169001TlLV_150393630...
# 2   [{'speakerId': '15315177009490016aEX_150393630...
# 20  [{'speakerId': '1533153526686001aze0_150393630...
# 21  [{'speakerId': '14574697717300035Hxm_150393630...
# 22  [{'speakerId': '14574694775980015e0D_150393630...
# 23  [{'speakerId': '1467230960339001h4Nj_150393630...
# 24  [{'speakerId': '1500580326390001qTtd_150393630...
# 25  [{'speakerId': '1470698803884001CfwZ_150393630...
# 26  [{'speakerId': '14664511836130012Qxc_150393630...
# 27  [{'speakerId': '1500578268510001KsST_150393630...
# 28  [{'speakerId': '1467230528322001hGg0_150393630...
# 29  [{'speakerId': '14574694988420015Jbn_150393630...
# 3   [{'speakerId': '14574694525770015tTj_150393630...
# 30  [{'speakerId': '1533153526686001aze0_150393630...
# 31  [{'speakerId': '1470698803884001CfwZ_150393630...
# 32  [{'speakerId': '14574696120130015JlG_150393630...
# 33  [{'speakerId': '145746943683700158HC_150393630...
# 34  [{'speakerId': '14574694354950015iFv_150393630...
# 35  [{'speakerId': '14574696616110015fCp_150393630...
# 36  [{'speakerId': '14574694733280025bh3_150393630...
# 37  [{'speakerId': '1533153526686001aze0_150393630...
# 38  [{'speakerId': '1533153526686001aze0_150393630...
# 39  [{'speakerId': '14574694370360025gMe_150393630...
# 4   [{'speakerId': '1533151159169001TlLV_150393630...
# 40  [{'speakerId': '14574697206660015bfV_150393630...
# 41  [{'speakerId': '14574694762980015eve_150393630...
# 42  [{'speakerId': '14574694748550015JRe_150393630...
# 43  [{'speakerId': '14574695098990015wUk_150393630...
# 44  [{'speakerId': '14574694711340015m5k_150393630...
# 45  [{'speakerId': '1500580326390001qTtd_150393630...
# 46  [{'speakerId': '145746944760700159kb_150393630...
# 47  [{'speakerId': '14574694422520015XTf_150393630...
# 48  [{'speakerId': '14574694422520015XTf_150393630...
# 49  [{'speakerId': '1500580326390001qTtd_150393630...
# 5   [{'speakerId': '14574694639010015kGi_150393630...
# 6   [{'speakerId': '1500580326390001qTtd_150393630...
# 7   [{'speakerId': '14574694685180025oHC_150393630...
# 8   [{'speakerId': '14574694459920025cpR_150393630...
# 9   [{'speakerId': '14574695070120015ey6_150393630...
#
#                                                 times  \
# 0   [{'sessionTimeID': '1532616475210001usPa', 'se...
# 1   [{'sessionTimeID': '1531945554973001z4Hi', 'se...
# 10  [{'sessionTimeID': '15352384203600012G04', 'se...
# 11  [{'sessionTimeID': '1538112369718001MoR2', 'se...
# 12  [{'sessionTimeID': '1535044864680001SZQw', 'se...
# 13  [{'sessionTimeID': '1535047180566001tTGP', 'se...
# 14  [{'sessionTimeID': '1531854081960001fkV5', 'se...
# 15  [{'sessionTimeID': '1533759384227001uIZh', 'se...
# 16  [{'sessionTimeID': '1533759287589001DyMn', 'se...
# 17  [{'sessionTimeID': '1533797930591001DtuZ', 'se...
# 18  [{'sessionTimeID': '1534548822332001jDNv', 'se...
# 19  [{'sessionTimeID': '15381125187210018fbH', 'se...
# 2   [{'sessionTimeID': '1535697245338001x3yZ', 'se...
# 20  [{'sessionTimeID': '1538112267267001PV2e', 'se...
# 21  [{'sessionTimeID': '1536195528781001YHbb', 'se...
# 22  [{'sessionTimeID': '1532734468296001S4ra', 'se...
# 23  [{'sessionTimeID': '1537150614045001Fc1v', 'se...
# 24  [{'sessionTimeID': '1537255427664001P8OT', 'se...
# 25  [{'sessionTimeID': '1537150687958001eoZ7', 'se...
# 26  [{'sessionTimeID': '1537150650927001PHnW', 'se...
# 27  [{'sessionTimeID': '1537150669415001Foxx', 'se...
# 28  [{'sessionTimeID': '1537150593997001PXcV', 'se...
# 29  [{'sessionTimeID': '1531854038107001ankr', 'se...
# 3   [{'sessionTimeID': '1531859121810001TdYU', 'se...
# 30  [{'sessionTimeID': '1535316983456001BNUt', 'se...
# 31  [{'sessionTimeID': '1538112283675001MFof', 'se...
# 32  [{'sessionTimeID': '15352234095720011o4W', 'se...
# 33  [{'sessionTimeID': '1535170950479001Bqi3', 'se...
# 34  [{'sessionTimeID': '1531849969460001fzY3', 'se...
# 35  [{'sessionTimeID': '1531769844473001acP5', 'se...
# 36  [{'sessionTimeID': '1539627763346001Nol6', 'se...
# 37  [{'sessionTimeID': '1538112532706001Pb5D', 'se...
# 38  [{'sessionTimeID': '1538112427579001MNeY', 'se...
# 39  [{'sessionTimeID': '1531848290901001fiBN', 'se...
# 4   [{'sessionTimeID': '15353154410710012PiP', 'se...
# 40  [{'sessionTimeID': '1535046699651001SvIb', 'se...
# 41  [{'sessionTimeID': '1531946578948001zDRs', 'se...
# 42  [{'sessionTimeID': '1531849529027001TJcf', 'se...
# 43  [{'sessionTimeID': '15320334995950015aXk', 'se...
# 44  [{'sessionTimeID': '1531945644126001zzma', 'se...
# 45  [{'sessionTimeID': '15381123375010018r1z', 'se...
# 46  [{'sessionTimeID': '1533758776080001MDuW', 'se...
# 47  [{'sessionTimeID': '1538112351906001PAkt', 'se...
# 48  [{'sessionTimeID': '1538112737368001PGzW', 'se...
# 49  [{'sessionTimeID': '1538112695700001MkPC', 'se...
# 5   [{'sessionTimeID': '1531853834216001TVkZ', 'se...
# 6   [{'sessionTimeID': '1535317184544001BYVj', 'se...
# 7   [{'sessionTimeID': '15343996004640012QHh', 'se...
# 8   [{'sessionTimeID': '1531861316059001fOyC', 'se...
# 9   [{'sessionTimeID': '1531861261596001T69W', 'se...
#
#                                                 title  \
# 0   A Database Proxy for Transparent High Availabi...
# 1   A Day in the Life of a Real-World Performance ...
# 10  Best Practices for Diagnosing and Troubleshoot...
# 11  Best Practices for Enterprise Application Perf...
# 12  Best Practices for Going Hybrid with Oracle's ...
# 13  Building Firewalls and Load Balancers on Oracl...
# 14  Building Real-Time Data in Web Applications wi...
# 15  Build Mobile/Progressive Web Apps: Oracle Visu...
# 16  Build Multilingual Digital Assistants/Chatbots...
# 17  Chat With Oracle SaaS Cloud Apps using Your Or...
# 18  Configure, Diagnose, Troubleshoot Security Ass...
# 19  Create a Rule in Oracle E-Business Tax to Dete...
# 2   A Deep Dive into Oracle's Artificial Intellige...
# 20  Create Database REST APIs for Mobile Apps Usin...
# 21  Creating and Maintaining Commerce Integrations...
# 22  Database Consolidation: Best Practices for Suc...
# 23  Deep Dive: An Introduction to Workflow Approva...
# 24  Deep Dive: Application Integration on Oracle C...
# 25       Deep Dive: Java Secure Coding Best Practices
# 26  Deep Dive: Oracle Big Data/Oracle Big Data Clo...
# 27  Deep Dive: Oracle Database 18c New Features: C...
# 28  Deep Dive: Oracle HCM Cloud: Getting Started w...
# 29  Developers: Don’t Be the Person Who Discombobu...
# 3   An Insider’s Guide to Oracle Autonomous Transa...
# 30  Develop, Implement, and Maintain Database REST...
# 31  Develop Robust Enterprise Applications with Ja...
# 32  Diamonds May Be Forever but Platinum Is Now: O...
# 33              Do We Still Need to Design Databases?
# 34  Eliminate Application Downtime with Oracle Dat...
# 35  Encrypt Your Crown Jewels and Manage Keys Effi...
# 36  Enhancing Oracle Fusion Applications Security ...
# 37  Expose Enterprise Integration Services as Cust...
# 38  Filter Big Data Streams Easily Using Java Streams
# 39                      Finally: DevOps for Databases
# 4   An Overview of Oracle Approvals Management Eng...
# 40  Five Inexpensive Tricks to Accelerate Oracle D...
# 41  Geo-Tagging, Geo-Enrichment, Geo-Fencing, and ...
# 42               Getting Started with Oracle and .NET
# 43  High Availability and Sharding Deep Dive with ...
# 44      How to Analyze Data Warehouse Data as a Graph
# 45                    How to Apply Policies to an API
# 46  How to Build a Decentralized Blockchain App wi...
# 47              How to Combine Data from Source Sites
# 48              How to Create a User-Managed Platform
# 49                     How to Create Web Applications
# 5   Application High Availability Best Practices a...
# 6            Application Integration on Oracle Cloud
# 7   Ask the Oracle Analytics Product Management an...
# 8   Autonomous Database Diagnostics Through Applie...
# 9   Autonomous Health for Oracle RAC Continuous Av...
#
#                         title_sort                      type oracle_speaker  \
# 0   adatabaseproxyfortransparenthi  Product Training Session              Y
# 1   adayinthelifeofarealworldperfo  Product Training Session              Y
# 10  bestpracticesfordiagnosingandt  Product Training Session              Y
# 11  bestpracticesforenterpriseappl  Product Training Session              Y
# 12  bestpracticesforgoinghybridwit  Product Training Session              Y
# 13  buildingfirewallsandloadbalanc  Product Training Session              Y
# 14  buildingrealtimedatainwebappli  Product Training Session              Y
# 15  buildmobileprogressivewebappso  Product Training Session              Y
# 16  buildmultilingualdigitalassist  Product Training Session              Y
# 17  chatwithoraclesaascloudappsusi  Product Training Session              Y
# 18  configurediagnosetroubleshoots  Product Training Session              Y
# 19  createaruleinoracleebusinessta  Product Training Session              Y
# 2   adeepdiveintooraclesartificial  Product Training Session              Y
# 20  createdatabaserestapisformobil  Product Training Session              Y
# 21  creatingandmaintainingcommerce  Product Training Session              Y
# 22  databaseconsolidationbestpract  Product Training Session              Y
# 23  deepdiveanintroductiontoworkfl  Product Training Session              Y
# 24  deepdiveapplicationintegration  Product Training Session              Y
# 25  deepdivejavasecurecodingbestpr  Product Training Session              Y
# 26  deepdiveoraclebigdataoraclebig  Product Training Session              Y
# 27  deepdiveoracledatabase18cnewfe  Product Training Session              Y
# 28  deepdiveoraclehcmcloudgettings  Product Training Session              Y
# 29  developersdontbethepersonwhodi  Product Training Session              Y
# 3   aninsidersguidetooracleautonom  Product Training Session              Y
# 30  developimplementandmaintaindat  Product Training Session              Y
# 31  developrobustenterpriseapplica  Product Training Session              Y
# 32  diamondsmaybeforeverbutplatinu  Product Training Session              Y
# 33  dowestillneedtodesigndatabases  Product Training Session              N
# 34  eliminateapplicationdowntimewi  Product Training Session              Y
# 35  encryptyourcrownjewelsandmanag  Product Training Session              Y
# 36  enhancingoraclefusionapplicati  Product Training Session              Y
# 37  exposeenterpriseintegrationser  Product Training Session              Y
# 38  filterbigdatastreamseasilyusin  Product Training Session              Y
# 39       finallydevopsfordatabases  Product Training Session              Y
# 4   anoverviewoforacleapprovalsman  Product Training Session              Y
# 40  fiveinexpensivetrickstoacceler  Product Training Session              Y
# 41  geotagginggeoenrichmentgeofenc  Product Training Session              Y
# 42  gettingstartedwithoracleandnet  Product Training Session              Y
# 43  highavailabilityandshardingdee  Product Training Session              Y
# 44  howtoanalyzedatawarehousedataa  Product Training Session              Y
# 45       howtoapplypoliciestoanapi  Product Training Session              Y
# 46  howtobuildadecentralizedblockc  Product Training Session              N
# 47  howtocombinedatafromsourcesite  Product Training Session              Y
# 48  howtocreateausermanagedplatfor  Product Training Session              Y
# 49      howtocreatewebapplications  Product Training Session              Y
# 5   applicationhighavailabilitybes  Product Training Session              Y
# 6   applicationintegrationonoracle  Product Training Session              Y
# 7   asktheoracleanalyticsproductma  Product Training Session              Y
# 8   autonomousdatabasediagnosticst  Product Training Session              Y
# 9   autonomoushealthfororacleracco  Product Training Session              Y
#
#    file_flag JavaOne Rockstar Oracle ACE Director Oracle Java Champion  \
# 0          Y                N                   N                    N
# 1          Y                N                   N                    N
# 10         Y                N                   N                    N
# 11         N                N                   N                    N
# 12         Y                N                   N                    N
# 13         Y                N                   N                    N
# 14         Y                N                   N                    N
# 15         Y                N                   N                    N
# 16         Y                N                   N                    N
# 17         Y                N                   N                    N
# 18         Y                N                   N                    N
# 19         Y                N                   N                    N
# 2          N                N                   N                    N
# 20         Y                N                   N                    N
# 21         N                N                   N                    N
# 22         Y                N                   N                    N
# 23         Y                N                   N                    N
# 24         Y                N                   N                    N
# 25         N                N                   N                    N
# 26         Y                N                   N                    N
# 27         Y                Y                   N                    N
# 28         Y                N                   N                    N
# 29         Y                N                   N                    N
# 3          Y                N                   N                    N
# 30         Y                N                   N                    N
# 31         N                N                   N                    N
# 32         N                N                   N                    N
# 33         Y                N                   Y                    N
# 34         Y                N                   N                    N
# 35         Y                N                   N                    N
# 36         Y                N                   N                    N
# 37         Y                N                   N                    N
# 38         Y                N                   N                    N
# 39         N                N                   N                    N
# 4          Y                N                   N                    N
# 40         Y                N                   N                    N
# 41         Y                N                   N                    N
# 42         Y                N                   N                    N
# 43         Y                N                   N                    N
# 44         Y                N                   N                    N
# 45         Y                N                   N                    N
# 46         Y                N                   N                    N
# 47         Y                N                   N                    N
# 48         Y                N                   N                    N
# 49         Y                N                   N                    N
# 5          Y                N                   N                    N
# 6          Y                N                   N                    N
# 7          N                N                   N                    N
# 8          Y                N                   N                    N
# 9          Y                N                   N                    N
#
#    Groundbreaker Ambassador
# 0                         N
# 1                         N
# 10                        N
# 11                        N
# 12                        N
# 13                        N
# 14                        N
# 15                        N
# 16                        N
# 17                        N
# 18                        N
# 19                        N
# 2                         N
# 20                        N
# 21                        N
# 22                        N
# 23                        N
# 24                        N
# 25                        N
# 26                        N
# 27                        N
# 28                        N
# 29                        N
# 3                         N
# 30                        N
# 31                        N
# 32                        N
# 33                        N
# 34                        N
# 35                        N
# 36                        N
# 37                        N
# 38                        N
# 39                        N
# 4                         N
# 40                        N
# 41                        N
# 42                        N
# 43                        N
# 44                        N
# 45                        N
# 46                        Y
# 47                        N
# 48                        N
# 49                        N
# 5                         N
# 6                         N
# 7                         N
# 8                         N
# 9                         N

# %%
#function to derive level for session
def session_level(session):
      level = ""
      # loop over speakers and their attributevalues; if any exist with attribute_id == specialdesignations and value == JavaOne Rockstar
      for x in session["attributevalues"][:]:
            if "attribute_id" in x: 
                if x["attribute_id"]=="specialdesignations":
                        if y["value"]== designation:
                            result="Y"
                        print (y["value"], " == ",result,"  ",designation)
      return result

# %% [markdown]
# #Persist Pandas Dataframe

# %% [markdown]
# One thing we want to be able to do with the data we gather, is to persist it for future use. We could store the data in a NoSQL database, a cloud storage service or simply as a local file. For now, let's simply do the latter.

# %%
ss.to_json("oow2018-sessions-wrangled.json", force_ascii=False)

# %%
dubss = pd.read_json("oow2018-sessions-wrangled.json")
dubss
# Out:
#    Groundbreaker Ambassador JavaOne Rockstar Oracle ACE Director  \
# 0                         N                N                   N
# 1                         N                N                   N
# 10                        N                N                   N
# 11                        N                N                   N
# 12                        N                N                   N
# 13                        N                N                   N
# 14                        N                N                   N
# 15                        N                N                   N
# 16                        N                N                   N
# 17                        N                N                   N
# 18                        N                N                   N
# 19                        N                N                   N
# 2                         N                N                   N
# 20                        N                N                   N
# 21                        N                N                   N
# 22                        N                N                   N
# 23                        N                N                   N
# 24                        N                N                   N
# 25                        N                N                   N
# 26                        N                N                   N
# 27                        N                Y                   N
# 28                        N                N                   N
# 29                        N                N                   N
# 3                         N                N                   N
# 30                        N                N                   N
# 31                        N                N                   N
# 32                        N                N                   N
# 33                        N                N                   Y
# 34                        N                N                   N
# 35                        N                N                   N
# 36                        N                N                   N
# 37                        N                N                   N
# 38                        N                N                   N
# 39                        N                N                   N
# 4                         N                N                   N
# 40                        N                N                   N
# 41                        N                N                   N
# 42                        N                N                   N
# 43                        N                N                   N
# 44                        N                N                   N
# 45                        N                N                   N
# 46                        Y                N                   N
# 47                        N                N                   N
# 48                        N                N                   N
# 49                        N                N                   N
# 5                         N                N                   N
# 6                         N                N                   N
# 7                         N                N                   N
# 8                         N                N                   N
# 9                         N                N                   N
#
#    Oracle Java Champion                                           abstract  \
# 0                     N  What if you could benefit from new database qu...
# 1                     N  How does a real-world performance engineer int...
# 10                    N  Understand the tools and techniques available ...
# 11                    N  This session covers the best practices for per...
# 12                    N  Should you refresh your current x86 hardware a...
# 13                    N  Oracle Linux 7 offers the ability to natively ...
# 14                    N  Real-time data is an increasingly popular topi...
# 15                    N  Enterprises need to rapidly react to the chang...
# 16                    N  Digital assistant and chatbot support for any ...
# 17                    N  Do you wish Oracle Digital Assistant could ask...
# 18                    N  In this session learn how to implement and use...
# 19                    N  In this session learn how to set up a simple r...
# 2                     N  This session takes a deep dive into how the Or...
# 20                    N  In this session learn how to shape enterprise ...
# 21                    N  The word “integration” has always conjured up ...
# 22                    N  Consolidating databases requires configuring t...
# 23                    N  This four-hour session will provide an overvie...
# 24                    N  In this four-hour session learn how to meet yo...
# 25                    N  This four-hour session covers secure coding be...
# 26                    N  In this four-hour session learn about Oracle B...
# 27                    N  In this session take a deep-dive into the late...
# 28                    N  In this four-hour session learn how to use the...
# 29                    N  Developers are under increasing  pressure to d...
# 3                     N  Who says setting up and operating mission crit...
# 30                    N  RESTful web services are gaining popularity be...
# 31                    N  This session covers how to use Lambda Expressi...
# 32                    N  Take advantage of the free SaaS application tr...
# 33                    N  Hardware is cheap, the cloud is here, and reso...
# 34                    N  Oracle Database brings unprecedented high avai...
# 35                    N  Encrypting sensitive data has become a must in...
# 36                    N  Integrating Oracle Fusion Applications such as...
# 37                    N  This session explores how to quickly add a RES...
# 38                    N  In this session learn how to filter, compute, ...
# 39                    N  DevOps has become a common practice in the IT ...
# 4                     N  Oracle Approvals Management is a highly extens...
# 40                    N  In this session learn how to unlock even more ...
# 41                    N  Oracle technologies make it easy to include lo...
# 42                    N  How do you get started using Visual Studio to ...
# 43                    N  Do you need global availability and scalabilit...
# 44                    N  In this session gain new insights into your an...
# 45                    N  In this session learn how to apply policies to...
# 46                    N  During this deep-dive session learn how to bui...
# 47                    N  In this session learn how to combine data from...
# 48                    N  In this session learn how to create a user-man...
# 49                    N  In this session learn how to create a web appl...
# 5                     N  Make your applications run without interruptio...
# 6                     N  In this session learn how to meet your applica...
# 7                     N  In this session join development and product m...
# 8                     N  In this session learn how to enable the autono...
# 9                     N  In this session learn about the latest autonom...
#
#                                       attributevalues     code  \
# 0   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4070
# 1   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4026
# 10  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4567
# 11  [{'value': 'Product Training Session', 'attrib...  TRN6620
# 12  [{'value': 'Product Training Session', 'attrib...  TRN4782
# 13  [{'value': 'Intermediate', 'attributevalue_id'...  TRN1795
# 14  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4081
# 15  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5774
# 16  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5777
# 17  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5792
# 18  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4568
# 19  [{'value': 'Product Training Session', 'attrib...  TRN6615
# 2   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4631
# 20  [{'value': 'Product Training Session', 'attrib...  TRN6616
# 21  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6154
# 22  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN5157
# 23  [{'value': 'Product Training Session', 'attrib...  TRN6461
# 24  [{'value': '- Integration', 'attributevalue_id...  TRN6458
# 25  [{'value': 'Product Training Session', 'attrib...  TRN6463
# 26  [{'value': 'Product Training Session', 'attrib...  TRN6460
# 27  [{'value': 'Product Training Session', 'attrib...  TRN6462
# 28  [{'value': 'Product Training Session', 'attrib...  TRN6459
# 29  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4096
# 3   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN3979
# 30  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6451
# 31  [{'value': 'Product Training Session', 'attrib...  TRN6619
# 32  [{'value': 'Product Training Session', 'attrib...  TRN6356
# 33  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1743
# 34  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4086
# 35  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4106
# 36  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6963
# 37  [{'value': 'Product Training Session', 'attrib...  TRN6618
# 38  [{'value': 'Product Training Session', 'attrib...  TRN6617
# 39  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4088
# 4   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6446
# 40  [{'value': 'Advanced', 'attributevalue_id': '1...  TRN4499
# 41  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4095
# 42  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4082
# 43  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4032
# 44  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4099
# 45  [{'value': 'Product Training Session', 'attrib...  TRN6511
# 46  [{'value': 'Beginner', 'attributevalue_id': '1...  TRN1918
# 47  [{'value': 'Product Training Session', 'attrib...  TRN6520
# 48  [{'value': 'Product Training Session', 'attrib...  TRN6522
# 49  [{'value': 'Product Training Session', 'attrib...  TRN6516
# 5   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN4078
# 6   [{'value': 'Product Training Session', 'attrib...  TRN6352
# 7   [{'value': 'Beginner', 'attributevalue_id': '1...  TRN6168
# 8   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4162
# 9   [{'value': 'Intermediate', 'attributevalue_id'...  TRN4163
#
#                event eventCode file_flag  \
# 0   Oracle OpenWorld     oow18         Y
# 1   Oracle OpenWorld     oow18         Y
# 10  Oracle OpenWorld     oow18         Y
# 11  Oracle OpenWorld     oow18         N
# 12  Oracle OpenWorld     oow18         Y
# 13  Oracle OpenWorld     oow18         Y
# 14  Oracle OpenWorld     oow18         Y
# 15  Oracle OpenWorld     oow18         Y
# 16  Oracle OpenWorld     oow18         Y
# 17  Oracle OpenWorld     oow18         Y
# 18  Oracle OpenWorld     oow18         Y
# 19  Oracle OpenWorld     oow18         Y
# 2   Oracle OpenWorld     oow18         N
# 20  Oracle OpenWorld     oow18         Y
# 21  Oracle OpenWorld     oow18         N
# 22  Oracle OpenWorld     oow18         Y
# 23  Oracle OpenWorld     oow18         Y
# 24  Oracle OpenWorld     oow18         Y
# 25  Oracle OpenWorld     oow18         N
# 26  Oracle OpenWorld     oow18         Y
# 27  Oracle OpenWorld     oow18         Y
# 28  Oracle OpenWorld     oow18         Y
# 29  Oracle OpenWorld     oow18         Y
# 3   Oracle OpenWorld     oow18         Y
# 30  Oracle OpenWorld     oow18         Y
# 31  Oracle OpenWorld     oow18         N
# 32  Oracle OpenWorld     oow18         N
# 33  Oracle OpenWorld     oow18         Y
# 34  Oracle OpenWorld     oow18         Y
# 35  Oracle OpenWorld     oow18         Y
# 36  Oracle OpenWorld     oow18         Y
# 37  Oracle OpenWorld     oow18         Y
# 38  Oracle OpenWorld     oow18         Y
# 39  Oracle OpenWorld     oow18         N
# 4   Oracle OpenWorld     oow18         Y
# 40  Oracle OpenWorld     oow18         Y
# 41  Oracle OpenWorld     oow18         Y
# 42  Oracle OpenWorld     oow18         Y
# 43  Oracle OpenWorld     oow18         Y
# 44  Oracle OpenWorld     oow18         Y
# 45  Oracle OpenWorld     oow18         Y
# 46  Oracle OpenWorld     oow18         Y
# 47  Oracle OpenWorld     oow18         Y
# 48  Oracle OpenWorld     oow18         Y
# 49  Oracle OpenWorld     oow18         Y
# 5   Oracle OpenWorld     oow18         Y
# 6   Oracle OpenWorld     oow18         Y
# 7   Oracle OpenWorld     oow18         N
# 8   Oracle OpenWorld     oow18         Y
# 9   Oracle OpenWorld     oow18         Y
#
#                                                 files  length oracle_speaker  \
# 0   [{'fileId': '1540594881063001PjdE', 'filename'...      45              Y
# 1   [{'fileId': '1540053090863001JeFM', 'filename'...      45              Y
# 10  [{'fileId': '1539988618000001VcCe', 'filename'...      45              Y
# 11                                               None      20              Y
# 12  [{'fileId': '1541718307822001nnE5', 'filename'...      45              Y
# 13  [{'fileId': '1540823655456001S2yU', 'filename'...      45              Y
# 14  [{'fileId': '1540586960748001awpB', 'filename'...      45              Y
# 15  [{'fileId': '1540498947195001Q0Ng', 'filename'...      45              Y
# 16  [{'fileId': '1540304567821001vNsN', 'filename'...      45              Y
# 17  [{'fileId': '1542151051287001R7i9', 'filename'...      45              Y
# 18  [{'fileId': '1540476654486001kh1V', 'filename'...      45              Y
# 19  [{'fileId': '1539815634830001z0Yt', 'filename'...      20              Y
# 2                                                None      45              Y
# 20  [{'fileId': '1540138774225001QP4j', 'filename'...      20              Y
# 21                                               None      45              Y
# 22  [{'fileId': '1542289822562001Wyh2', 'filename'...      45              Y
# 23  [{'fileId': '1540267572704001DPfY', 'filename'...     240              Y
# 24  [{'fileId': '1539983113140001dUD6', 'filename'...     240              Y
# 25                                               None     240              Y
# 26  [{'fileId': '1540527681659001JDvx', 'filename'...     240              Y
# 27  [{'fileId': '1540231956194001DVjv', 'filename'...     240              Y
# 28  [{'fileId': '1539725236806001lwQU', 'filename'...     240              Y
# 29  [{'fileId': '1540795935251001S515', 'filename'...      45              Y
# 3   [{'fileId': '1540586876838001Ph9B', 'filename'...      45              Y
# 30  [{'fileId': '15401387571180016fMd', 'filename'...      45              Y
# 31                                               None      20              Y
# 32                                               None      45              Y
# 33  [{'fileId': '1540792881998001P1gG', 'filename'...      45              N
# 34  [{'fileId': '1540524901214001DeiN', 'filename'...      45              Y
# 35  [{'fileId': '1540946073032001t4Xq', 'filename'...      45              Y
# 36  [{'fileId': '1540835441272001sbxy', 'filename'...      45              Y
# 37  [{'fileId': '1540138803558001Jt4Z', 'filename'...      20              Y
# 38  [{'fileId': '1540138790214001vcVs', 'filename'...      20              Y
# 39                                               None      45              Y
# 4   [{'fileId': '1539815058569001lvIK', 'filename'...      45              Y
# 40  [{'fileId': '15414557470710017n4B', 'filename'...      45              Y
# 41  [{'fileId': '1540906576250001scXJ', 'filename'...      45              Y
# 42  [{'fileId': '1543251169356001Rr8J', 'filename'...      45              Y
# 43  [{'fileId': '1541456703248001Bmgl', 'filename'...      45              Y
# 44  [{'fileId': '1540993657058001xLIc', 'filename'...      45              Y
# 45  [{'fileId': '1539983314113001Ddd3', 'filename'...      20              Y
# 46  [{'fileId': '1540133033796001JEIg', 'filename'...      45              N
# 47  [{'fileId': '1540221835507001QL6R', 'filename'...      20              Y
# 48  [{'fileId': '1540220944732001JNkX', 'filename'...      20              Y
# 49  [{'fileId': '1539983570031001QKVJ', 'filename'...      20              Y
# 5   [{'fileId': '1540591572080001fr6Q', 'filename'...      45              Y
# 6   [{'fileId': '1539979883463001Voaf', 'filename'...      45              Y
# 7                                                None      45              Y
# 8   [{'fileId': '1541467971650001UYFt', 'filename'...      45              Y
# 9   [{'fileId': '1540528741382001Q6i3', 'filename'...      45              Y
#
#                                          participants  \
# 0   [{'speakerId': '14574694377280015QNA_150393630...
# 1   [{'speakerId': '145746969078000151fg_150393630...
# 10  [{'speakerId': '1468532302119001DtNf_150393630...
# 11  [{'speakerId': '1470698803884001CfwZ_150393630...
# 12  [{'speakerId': '14574694661200015oeh_150393630...
# 13  [{'speakerId': '1521580422142001cXpX_150393630...
# 14  [{'speakerId': '14574694955970015EaV_150393630...
# 15  [{'speakerId': '14574696964400015ReA_150393630...
# 16  [{'speakerId': '1462125550493001D3Xz_150393630...
# 17  [{'speakerId': '1515103283372001FgzI_150393630...
# 18  [{'speakerId': '1472560122691001TA73_150393630...
# 19  [{'speakerId': '1533151159169001TlLV_150393630...
# 2   [{'speakerId': '15315177009490016aEX_150393630...
# 20  [{'speakerId': '1533153526686001aze0_150393630...
# 21  [{'speakerId': '14574697717300035Hxm_150393630...
# 22  [{'speakerId': '14574694775980015e0D_150393630...
# 23  [{'speakerId': '1467230960339001h4Nj_150393630...
# 24  [{'speakerId': '1500580326390001qTtd_150393630...
# 25  [{'speakerId': '1470698803884001CfwZ_150393630...
# 26  [{'speakerId': '14664511836130012Qxc_150393630...
# 27  [{'speakerId': '1500578268510001KsST_150393630...
# 28  [{'speakerId': '1467230528322001hGg0_150393630...
# 29  [{'speakerId': '14574694988420015Jbn_150393630...
# 3   [{'speakerId': '14574694525770015tTj_150393630...
# 30  [{'speakerId': '1533153526686001aze0_150393630...
# 31  [{'speakerId': '1470698803884001CfwZ_150393630...
# 32  [{'speakerId': '14574696120130015JlG_150393630...
# 33  [{'speakerId': '145746943683700158HC_150393630...
# 34  [{'speakerId': '14574694354950015iFv_150393630...
# 35  [{'speakerId': '14574696616110015fCp_150393630...
# 36  [{'speakerId': '14574694733280025bh3_150393630...
# 37  [{'speakerId': '1533153526686001aze0_150393630...
# 38  [{'speakerId': '1533153526686001aze0_150393630...
# 39  [{'speakerId': '14574694370360025gMe_150393630...
# 4   [{'speakerId': '1533151159169001TlLV_150393630...
# 40  [{'speakerId': '14574697206660015bfV_150393630...
# 41  [{'speakerId': '14574694762980015eve_150393630...
# 42  [{'speakerId': '14574694748550015JRe_150393630...
# 43  [{'speakerId': '14574695098990015wUk_150393630...
# 44  [{'speakerId': '14574694711340015m5k_150393630...
# 45  [{'speakerId': '1500580326390001qTtd_150393630...
# 46  [{'speakerId': '145746944760700159kb_150393630...
# 47  [{'speakerId': '14574694422520015XTf_150393630...
# 48  [{'speakerId': '14574694422520015XTf_150393630...
# 49  [{'speakerId': '1500580326390001qTtd_150393630...
# 5   [{'speakerId': '14574694639010015kGi_150393630...
# 6   [{'speakerId': '1500580326390001qTtd_150393630...
# 7   [{'speakerId': '14574694685180025oHC_150393630...
# 8   [{'speakerId': '14574694459920025cpR_150393630...
# 9   [{'speakerId': '14574695070120015ey6_150393630...
#
#                                                 times  \
# 0   [{'sessionTimeID': '1532616475210001usPa', 'se...
# 1   [{'sessionTimeID': '1531945554973001z4Hi', 'se...
# 10  [{'sessionTimeID': '15352384203600012G04', 'se...
# 11  [{'sessionTimeID': '1538112369718001MoR2', 'se...
# 12  [{'sessionTimeID': '1535044864680001SZQw', 'se...
# 13  [{'sessionTimeID': '1535047180566001tTGP', 'se...
# 14  [{'sessionTimeID': '1531854081960001fkV5', 'se...
# 15  [{'sessionTimeID': '1533759384227001uIZh', 'se...
# 16  [{'sessionTimeID': '1533759287589001DyMn', 'se...
# 17  [{'sessionTimeID': '1533797930591001DtuZ', 'se...
# 18  [{'sessionTimeID': '1534548822332001jDNv', 'se...
# 19  [{'sessionTimeID': '15381125187210018fbH', 'se...
# 2   [{'sessionTimeID': '1535697245338001x3yZ', 'se...
# 20  [{'sessionTimeID': '1538112267267001PV2e', 'se...
# 21  [{'sessionTimeID': '1536195528781001YHbb', 'se...
# 22  [{'sessionTimeID': '1532734468296001S4ra', 'se...
# 23  [{'sessionTimeID': '1537150614045001Fc1v', 'se...
# 24  [{'sessionTimeID': '1537255427664001P8OT', 'se...
# 25  [{'sessionTimeID': '1537150687958001eoZ7', 'se...
# 26  [{'sessionTimeID': '1537150650927001PHnW', 'se...
# 27  [{'sessionTimeID': '1537150669415001Foxx', 'se...
# 28  [{'sessionTimeID': '1537150593997001PXcV', 'se...
# 29  [{'sessionTimeID': '1531854038107001ankr', 'se...
# 3   [{'sessionTimeID': '1531859121810001TdYU', 'se...
# 30  [{'sessionTimeID': '1535316983456001BNUt', 'se...
# 31  [{'sessionTimeID': '1538112283675001MFof', 'se...
# 32  [{'sessionTimeID': '15352234095720011o4W', 'se...
# 33  [{'sessionTimeID': '1535170950479001Bqi3', 'se...
# 34  [{'sessionTimeID': '1531849969460001fzY3', 'se...
# 35  [{'sessionTimeID': '1531769844473001acP5', 'se...
# 36  [{'sessionTimeID': '1539627763346001Nol6', 'se...
# 37  [{'sessionTimeID': '1538112532706001Pb5D', 'se...
# 38  [{'sessionTimeID': '1538112427579001MNeY', 'se...
# 39  [{'sessionTimeID': '1531848290901001fiBN', 'se...
# 4   [{'sessionTimeID': '15353154410710012PiP', 'se...
# 40  [{'sessionTimeID': '1535046699651001SvIb', 'se...
# 41  [{'sessionTimeID': '1531946578948001zDRs', 'se...
# 42  [{'sessionTimeID': '1531849529027001TJcf', 'se...
# 43  [{'sessionTimeID': '15320334995950015aXk', 'se...
# 44  [{'sessionTimeID': '1531945644126001zzma', 'se...
# 45  [{'sessionTimeID': '15381123375010018r1z', 'se...
# 46  [{'sessionTimeID': '1533758776080001MDuW', 'se...
# 47  [{'sessionTimeID': '1538112351906001PAkt', 'se...
# 48  [{'sessionTimeID': '1538112737368001PGzW', 'se...
# 49  [{'sessionTimeID': '1538112695700001MkPC', 'se...
# 5   [{'sessionTimeID': '1531853834216001TVkZ', 'se...
# 6   [{'sessionTimeID': '1535317184544001BYVj', 'se...
# 7   [{'sessionTimeID': '15343996004640012QHh', 'se...
# 8   [{'sessionTimeID': '1531861316059001fOyC', 'se...
# 9   [{'sessionTimeID': '1531861261596001T69W', 'se...
#
#                                                 title  \
# 0   A Database Proxy for Transparent High Availabi...
# 1   A Day in the Life of a Real-World Performance ...
# 10  Best Practices for Diagnosing and Troubleshoot...
# 11  Best Practices for Enterprise Application Perf...
# 12  Best Practices for Going Hybrid with Oracle's ...
# 13  Building Firewalls and Load Balancers on Oracl...
# 14  Building Real-Time Data in Web Applications wi...
# 15  Build Mobile/Progressive Web Apps: Oracle Visu...
# 16  Build Multilingual Digital Assistants/Chatbots...
# 17  Chat With Oracle SaaS Cloud Apps using Your Or...
# 18  Configure, Diagnose, Troubleshoot Security Ass...
# 19  Create a Rule in Oracle E-Business Tax to Dete...
# 2   A Deep Dive into Oracle's Artificial Intellige...
# 20  Create Database REST APIs for Mobile Apps Usin...
# 21  Creating and Maintaining Commerce Integrations...
# 22  Database Consolidation: Best Practices for Suc...
# 23  Deep Dive: An Introduction to Workflow Approva...
# 24  Deep Dive: Application Integration on Oracle C...
# 25       Deep Dive: Java Secure Coding Best Practices
# 26  Deep Dive: Oracle Big Data/Oracle Big Data Clo...
# 27  Deep Dive: Oracle Database 18c New Features: C...
# 28  Deep Dive: Oracle HCM Cloud: Getting Started w...
# 29  Developers: Don’t Be the Person Who Discombobu...
# 3   An Insider’s Guide to Oracle Autonomous Transa...
# 30  Develop, Implement, and Maintain Database REST...
# 31  Develop Robust Enterprise Applications with Ja...
# 32  Diamonds May Be Forever but Platinum Is Now: O...
# 33              Do We Still Need to Design Databases?
# 34  Eliminate Application Downtime with Oracle Dat...
# 35  Encrypt Your Crown Jewels and Manage Keys Effi...
# 36  Enhancing Oracle Fusion Applications Security ...
# 37  Expose Enterprise Integration Services as Cust...
# 38  Filter Big Data Streams Easily Using Java Streams
# 39                      Finally: DevOps for Databases
# 4   An Overview of Oracle Approvals Management Eng...
# 40  Five Inexpensive Tricks to Accelerate Oracle D...
# 41  Geo-Tagging, Geo-Enrichment, Geo-Fencing, and ...
# 42               Getting Started with Oracle and .NET
# 43  High Availability and Sharding Deep Dive with ...
# 44      How to Analyze Data Warehouse Data as a Graph
# 45                    How to Apply Policies to an API
# 46  How to Build a Decentralized Blockchain App wi...
# 47              How to Combine Data from Source Sites
# 48              How to Create a User-Managed Platform
# 49                     How to Create Web Applications
# 5   Application High Availability Best Practices a...
# 6            Application Integration on Oracle Cloud
# 7   Ask the Oracle Analytics Product Management an...
# 8   Autonomous Database Diagnostics Through Applie...
# 9   Autonomous Health for Oracle RAC Continuous Av...
#
#                         title_sort                      type
# 0   adatabaseproxyfortransparenthi  Product Training Session
# 1   adayinthelifeofarealworldperfo  Product Training Session
# 10  bestpracticesfordiagnosingandt  Product Training Session
# 11  bestpracticesforenterpriseappl  Product Training Session
# 12  bestpracticesforgoinghybridwit  Product Training Session
# 13  buildingfirewallsandloadbalanc  Product Training Session
# 14  buildingrealtimedatainwebappli  Product Training Session
# 15  buildmobileprogressivewebappso  Product Training Session
# 16  buildmultilingualdigitalassist  Product Training Session
# 17  chatwithoraclesaascloudappsusi  Product Training Session
# 18  configurediagnosetroubleshoots  Product Training Session
# 19  createaruleinoracleebusinessta  Product Training Session
# 2   adeepdiveintooraclesartificial  Product Training Session
# 20  createdatabaserestapisformobil  Product Training Session
# 21  creatingandmaintainingcommerce  Product Training Session
# 22  databaseconsolidationbestpract  Product Training Session
# 23  deepdiveanintroductiontoworkfl  Product Training Session
# 24  deepdiveapplicationintegration  Product Training Session
# 25  deepdivejavasecurecodingbestpr  Product Training Session
# 26  deepdiveoraclebigdataoraclebig  Product Training Session
# 27  deepdiveoracledatabase18cnewfe  Product Training Session
# 28  deepdiveoraclehcmcloudgettings  Product Training Session
# 29  developersdontbethepersonwhodi  Product Training Session
# 3   aninsidersguidetooracleautonom  Product Training Session
# 30  developimplementandmaintaindat  Product Training Session
# 31  developrobustenterpriseapplica  Product Training Session
# 32  diamondsmaybeforeverbutplatinu  Product Training Session
# 33  dowestillneedtodesigndatabases  Product Training Session
# 34  eliminateapplicationdowntimewi  Product Training Session
# 35  encryptyourcrownjewelsandmanag  Product Training Session
# 36  enhancingoraclefusionapplicati  Product Training Session
# 37  exposeenterpriseintegrationser  Product Training Session
# 38  filterbigdatastreamseasilyusin  Product Training Session
# 39       finallydevopsfordatabases  Product Training Session
# 4   anoverviewoforacleapprovalsman  Product Training Session
# 40  fiveinexpensivetrickstoacceler  Product Training Session
# 41  geotagginggeoenrichmentgeofenc  Product Training Session
# 42  gettingstartedwithoracleandnet  Product Training Session
# 43  highavailabilityandshardingdee  Product Training Session
# 44  howtoanalyzedatawarehousedataa  Product Training Session
# 45       howtoapplypoliciestoanapi  Product Training Session
# 46  howtobuildadecentralizedblockc  Product Training Session
# 47  howtocombinedatafromsourcesite  Product Training Session
# 48  howtocreateausermanagedplatfor  Product Training Session
# 49      howtocreatewebapplications  Product Training Session
# 5   applicationhighavailabilitybes  Product Training Session
# 6   applicationintegrationonoracle  Product Training Session
# 7   asktheoracleanalyticsproductma  Product Training Session
# 8   autonomousdatabasediagnosticst  Product Training Session
# 9   autonomoushealthfororacleracco  Product Training Session
